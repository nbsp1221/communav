# %%
# 다른 경로에 있는 모듈을 가져오기 위해 절대 경로 추가

import os
import sys

root = os.path.join(os.path.abspath(os.getcwd()), '..', '..')
root = os.path.normpath(root)

if root not in sys.path:
    sys.path.insert(0, root)

# %%
# 필요한 라이브러리 로드

import emoji
import json
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import random
import re
import torch
from communav.utils import db
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from soynlp.normalizer import repeat_normalize
from tqdm import tqdm
from transformers import AutoModelForSequenceClassification, AutoTokenizer, get_linear_schedule_with_warmup
# Out:
# /tmp/ipykernel_929215/2000937440.py:8: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# 카테고리 정의

CATEGORIES = {
    0: '자유',
    1: '학사',
    2: '장학 · 행정',
    3: '학교생활',
    4: '수업',
    5: '수업/이과',
    6: '수업/문과',
    7: '캠퍼스',
    8: '취업 · 진로',
    9: '일상생활',
    10: '음식점 · 카페',
    11: '취미 · 여가',
    12: '인간관계',
    13: '병역'
}

# %%
# 파라미터 설정

TABLE_NAME = 'everytime_article_dataset_v1'
MODEL_ID = '.model-iteration-10-epoch-13-0.9545'
TOKENIZER_ID = '.model-iteration-10-epoch-13-0.9545'
SEED = 42
USE_RANDOM_SEED = True
NUM_LABELS = len(CATEGORIES)
MAX_LENGTH = 128
METRIC_AVERAGE = 'weighted'
METRIC_ZERO_DIVISION = 0
BATCH_SIZE = 32
THRESHOLD = 0.5

# %%
# 랜덤 시드 고정

if torch.cuda.is_available():
    device = torch.device('cuda')
    print('There are %d GPU(s) available.' % torch.cuda.device_count())
    print('We will use the GPU:', torch.cuda.get_device_name(0))
else:
    device = torch.device('cpu')
    print('No GPU available, using the CPU instead.')

if not USE_RANDOM_SEED:
    random.seed(SEED)
    np.random.seed(SEED)
    torch.manual_seed(SEED)
    if device.type == 'cuda':
        torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 3060 Ti

# %%
# 커뮤니티 게시글 데이터 로드

connection = db.get_connection()
cursor = connection.cursor()

cursor.execute(f'''
    SELECT * FROM {TABLE_NAME}
''')
original_articles = cursor.fetchall()
print(f'Loaded {len(original_articles)} articles.')

cursor.close()
db.close_connection()
# Out:
# Connected to DB successfully.
# Loaded 299314 articles.

# %%
# 가져온 데이터의 일부를 출력

for article in original_articles[:20]:
    print(article)
# Out:
# {'id': 1, 'article_id': 21479637, 'title': '어제 비마관 화장실에서 핸드폰 찾아주신분!', 'text': '제가 경황이 없어서 감사하다고도 못 했네요.\n정말 감사합니다!!!', 'category_id': 9, 'is_verified': 1, 'possible_category_id': 9, 'probs_category_0': 0.000296279, 'probs_category_1': 9.15862e-05, 'probs_category_2': 0.000163286, 'probs_category_3': 0.000308967, 'probs_category_4': 8.23562e-06, 'probs_category_5': 7.15753e-05, 'probs_category_6': 8.95406e-06, 'probs_category_7': 0.000362028, 'probs_category_8': 0.000120989, 'probs_category_9': 0.997927, 'probs_category_10': 8.63704e-05, 'probs_category_11': 0.000422414, 'probs_category_12': 0.000116256, 'probs_category_13': 1.63995e-05}
# {'id': 2, 'article_id': 21480514, 'title': '클럽좋아하시는분 계세요~?', 'text': '남자 신입생인데 주말에갈려하는데 같이가실분 괌', 'category_id': None, 'is_verified': None, 'possible_category_id': 11, 'probs_category_0': 0.000195543, 'probs_category_1': 5.59121e-05, 'probs_category_2': 1.22078e-05, 'probs_category_3': 0.00166554, 'probs_category_4': 0.000262282, 'probs_category_5': 0.00054059, 'probs_category_6': 0.000315549, 'probs_category_7': 0.000127943, 'probs_category_8': 0.000138363, 'probs_category_9': 0.00122107, 'probs_category_10': 0.000342414, 'probs_category_11': 0.911652, 'probs_category_12': 0.0832625, 'probs_category_13': 0.000208197}
# {'id': 3, 'article_id': 21480639, 'title': '조은문화사 몇시에 보통 열리나요??', 'text': '1교시 수업 책 찾아야되서', 'category_id': 7, 'is_verified': 1, 'possible_category_id': 7, 'probs_category_0': 4.0224e-05, 'probs_category_1': 2.93139e-05, 'probs_category_2': 0.000130389, 'probs_category_3': 0.000274238, 'probs_category_4': 6.40644e-05, 'probs_category_5': 0.000192655, 'probs_category_6': 0.000111605, 'probs_category_7': 0.998205, 'probs_category_8': 2.54862e-05, 'probs_category_9': 0.000277536, 'probs_category_10': 0.000348676, 'probs_category_11': 0.000157135, 'probs_category_12': 2.43085e-05, 'probs_category_13': 0.00011917}
# {'id': 4, 'article_id': 21481049, 'title': '전공수업듣는데', 'text': '복학한거처럼 보이는 형이 열심히는 하시던데 뭔가 군대갔다고오고 모든걸 까먹은 자기를 자책하듯이 수업듣는걸 보고 나도 3년후에 저러겠구나 싶더라... ㅠㅠ', 'category_id': 4, 'is_verified': None, 'possible_category_id': 4, 'probs_category_0': 0.000176572, 'probs_category_1': 0.000263026, 'probs_category_2': 0.000178103, 'probs_category_3': 0.000193896, 'probs_category_4': 0.996828, 'probs_category_5': 0.00051715, 'probs_category_6': 0.000364214, 'probs_category_7': 0.000112438, 'probs_category_8': 0.000617094, 'probs_category_9': 1.64144e-05, 'probs_category_10': 0.000127529, 'probs_category_11': 0.000190873, 'probs_category_12': 0.000195463, 'probs_category_13': 0.000219611}
# {'id': 5, 'article_id': 21481575, 'title': '정문에 있는 인쇄집들 몇시까지 하는지 아시나요?', 'text': '9시 넘어야 갈수있을거 같은데\n열어 있을지..', 'category_id': 7, 'is_verified': 1, 'possible_category_id': 7, 'probs_category_0': 3.31077e-05, 'probs_category_1': 3.16351e-05, 'probs_category_2': 0.000135744, 'probs_category_3': 0.000206084, 'probs_category_4': 6.79767e-05, 'probs_category_5': 0.000240959, 'probs_category_6': 0.000126002, 'probs_category_7': 0.998273, 'probs_category_8': 2.65404e-05, 'probs_category_9': 0.000228855, 'probs_category_10': 0.00036766, 'probs_category_11': 0.000126637, 'probs_category_12': 2.14676e-05, 'probs_category_13': 0.000113799}
# {'id': 6, 'article_id': 21482091, 'title': '이런사람들 많나?', 'text': '신입생 새터때 번호교환하고 학교서 인사만좀 하는사이였다가 연락 한 번도 안하고 군대가고 카톡친추는 되어있어서 누군지는 알고 복학하고 오니 서로 얼굴은아는데 인사하기도 민망하고 껄끄러운사이 너무 불편하다 엮일일 없으면 상관없는데 자꾸 마주치면 괜히 불편함', 'category_id': None, 'is_verified': None, 'possible_category_id': 3, 'probs_category_0': 0.00114792, 'probs_category_1': 6.53402e-05, 'probs_category_2': 3.62503e-05, 'probs_category_3': 0.980285, 'probs_category_4': 0.000164103, 'probs_category_5': 9.34017e-05, 'probs_category_6': 6.84505e-05, 'probs_category_7': 0.000154782, 'probs_category_8': 0.0013515, 'probs_category_9': 0.000435739, 'probs_category_10': 7.4479e-05, 'probs_category_11': 0.00103345, 'probs_category_12': 0.00111528, 'probs_category_13': 0.0139738}
# {'id': 7, 'article_id': 21482097, 'title': '해상도!', 'text': 'UHD 즉 4K면 코딩할때 글자 잘 안보이겠죠?\n그냥 FHD면 충분?', 'category_id': None, 'is_verified': None, 'possible_category_id': 9, 'probs_category_0': 0.000131393, 'probs_category_1': 0.00125548, 'probs_category_2': 0.000105728, 'probs_category_3': 0.00302609, 'probs_category_4': 9.33928e-05, 'probs_category_5': 0.00994397, 'probs_category_6': 8.17794e-05, 'probs_category_7': 0.00356971, 'probs_category_8': 0.000447281, 'probs_category_9': 0.97715, 'probs_category_10': 0.000279645, 'probs_category_11': 0.00367323, 'probs_category_12': 0.000191172, 'probs_category_13': 5.09343e-05}
# {'id': 8, 'article_id': 21482121, 'title': '문화유목시대 교재뭔가요', 'text': '정정기간때 신청해서 잘 모르겠어요. ㅠㅠ 계획서보니까 고른다고하는데 뭐에요?', 'category_id': 6, 'is_verified': None, 'possible_category_id': 6, 'probs_category_0': 0.000348475, 'probs_category_1': 0.000102621, 'probs_category_2': 0.000127307, 'probs_category_3': 0.000144229, 'probs_category_4': 0.000233274, 'probs_category_5': 0.000631772, 'probs_category_6': 0.99604, 'probs_category_7': 0.00134252, 'probs_category_8': 8.33146e-05, 'probs_category_9': 1.95601e-05, 'probs_category_10': 0.000106534, 'probs_category_11': 0.000530515, 'probs_category_12': 0.000186819, 'probs_category_13': 0.000103029}
# {'id': 9, 'article_id': 21482730, 'title': '난', 'text': '멋있어 멋있어', 'category_id': None, 'is_verified': None, 'possible_category_id': 11, 'probs_category_0': 0.0149573, 'probs_category_1': 8.58992e-05, 'probs_category_2': 5.32028e-05, 'probs_category_3': 0.00830653, 'probs_category_4': 0.000425181, 'probs_category_5': 0.00025172, 'probs_category_6': 0.000377101, 'probs_category_7': 0.000272245, 'probs_category_8': 0.000487663, 'probs_category_9': 0.00591495, 'probs_category_10': 0.000563317, 'probs_category_11': 0.910896, 'probs_category_12': 0.0565097, 'probs_category_13': 0.000899667}
# {'id': 10, 'article_id': 21483558, 'title': '내일 공강이다', 'text': '불기둥 같은 월화수를 마치고 목금이 오긴 왔네...', 'category_id': None, 'is_verified': None, 'possible_category_id': 3, 'probs_category_0': 0.000101582, 'probs_category_1': 4.67125e-05, 'probs_category_2': 8.39176e-06, 'probs_category_3': 0.997856, 'probs_category_4': 0.000145834, 'probs_category_5': 0.000342744, 'probs_category_6': 5.31964e-05, 'probs_category_7': 0.000113219, 'probs_category_8': 0.000248784, 'probs_category_9': 0.000121338, 'probs_category_10': 3.55251e-05, 'probs_category_11': 0.000622191, 'probs_category_12': 7.24771e-05, 'probs_category_13': 0.000231802}
# {'id': 11, 'article_id': 21483780, 'title': '힙동 들어가고싶긴한데', 'text': '커버밖에 못하고\n리얼 힙찔이라 엄두가안난다', 'category_id': None, 'is_verified': None, 'possible_category_id': 11, 'probs_category_0': 0.000530297, 'probs_category_1': 0.000125062, 'probs_category_2': 1.61864e-05, 'probs_category_3': 0.323855, 'probs_category_4': 0.000730667, 'probs_category_5': 0.00156121, 'probs_category_6': 0.000386982, 'probs_category_7': 0.000220022, 'probs_category_8': 0.000477807, 'probs_category_9': 0.000969939, 'probs_category_10': 0.000241075, 'probs_category_11': 0.667532, 'probs_category_12': 0.00279894, 'probs_category_13': 0.000554915}
# {'id': 12, 'article_id': 21483803, 'title': '바람지원했는데요', 'text': '아직 연락이 안왔는데 다들 안온건가요!?', 'category_id': None, 'is_verified': None, 'possible_category_id': 9, 'probs_category_0': 0.000812407, 'probs_category_1': 0.00048463, 'probs_category_2': 0.000150045, 'probs_category_3': 0.0505976, 'probs_category_4': 0.000221741, 'probs_category_5': 0.0046748, 'probs_category_6': 0.000693556, 'probs_category_7': 0.0215738, 'probs_category_8': 0.000238969, 'probs_category_9': 0.706541, 'probs_category_10': 0.00123683, 'probs_category_11': 0.211082, 'probs_category_12': 0.0015367, 'probs_category_13': 0.000155852}
# {'id': 13, 'article_id': 21483822, 'title': '전자회로실험 파형이 물결처럼 나와야하는데 왜 난 일자로 나오지???;;', 'text': '이번에 복학해서 실험들으려는데 그냥 예비는 똑같이 따라하면 되는거 아닌가?\n왜 일자로만 나와....', 'category_id': 5, 'is_verified': None, 'possible_category_id': 5, 'probs_category_0': 3.54648e-06, 'probs_category_1': 0.000141142, 'probs_category_2': 5.53595e-06, 'probs_category_3': 0.000131423, 'probs_category_4': 0.000218836, 'probs_category_5': 0.998921, 'probs_category_6': 0.000188758, 'probs_category_7': 9.96452e-05, 'probs_category_8': 5.56387e-05, 'probs_category_9': 5.3104e-05, 'probs_category_10': 2.33627e-05, 'probs_category_11': 0.000108885, 'probs_category_12': 2.797e-05, 'probs_category_13': 2.10178e-05}
# {'id': 14, 'article_id': 21484291, 'title': '전자회로실험 파형이 물결처럼 나와야하는데 왜 난 일자로 나오지???;;', 'text': '이번에 복학해서 실험들으려는데 그냥 예비는 똑같이 따라하면 되는거 아닌가?\n왜 일자로만 나와....\n이건 회로인데 뭐가 잘못된거지요????;;', 'category_id': 5, 'is_verified': None, 'possible_category_id': 5, 'probs_category_0': 3.59016e-06, 'probs_category_1': 0.00012843, 'probs_category_2': 5.46344e-06, 'probs_category_3': 0.000135124, 'probs_category_4': 0.000227049, 'probs_category_5': 0.998922, 'probs_category_6': 0.000182774, 'probs_category_7': 9.85363e-05, 'probs_category_8': 5.72544e-05, 'probs_category_9': 5.18695e-05, 'probs_category_10': 2.35093e-05, 'probs_category_11': 0.000114115, 'probs_category_12': 2.83324e-05, 'probs_category_13': 2.20468e-05}
# {'id': 15, 'article_id': 21484434, 'title': '이쯤에서 질문', 'text': '전공서적 (2 3 4학년 상관없음)\n1. 새책산다\n2. 중고로 산다\n3. 제본뜬다\n4. 물려받는다\n새책사거나 중고사신분 또 질문\na. 중고로 판다\nb. 그냥 가지고 있는다\nc. 물려준다', 'category_id': None, 'is_verified': None, 'possible_category_id': 4, 'probs_category_0': 0.0356415, 'probs_category_1': 0.00741984, 'probs_category_2': 0.00424883, 'probs_category_3': 0.00175437, 'probs_category_4': 0.861603, 'probs_category_5': 0.00374928, 'probs_category_6': 0.0621169, 'probs_category_7': 0.00107096, 'probs_category_8': 0.0151925, 'probs_category_9': 0.000570996, 'probs_category_10': 0.000957427, 'probs_category_11': 0.00306209, 'probs_category_12': 0.00164006, 'probs_category_13': 0.000972052}
# {'id': 16, 'article_id': 21484856, 'title': '화공과 유기화학1수업 책 : 스미스 유기화학', 'text': '번역판 샀는데 원서없으면 시험보기힘든가요?', 'category_id': None, 'is_verified': None, 'possible_category_id': 5, 'probs_category_0': 3.82702e-06, 'probs_category_1': 0.000125476, 'probs_category_2': 5.72017e-06, 'probs_category_3': 0.000125429, 'probs_category_4': 0.000209493, 'probs_category_5': 0.998952, 'probs_category_6': 0.000179401, 'probs_category_7': 8.94354e-05, 'probs_category_8': 6.73868e-05, 'probs_category_9': 5.69853e-05, 'probs_category_10': 2.3745e-05, 'probs_category_11': 0.000106042, 'probs_category_12': 3.05428e-05, 'probs_category_13': 2.44085e-05}
# {'id': 17, 'article_id': 21485394, 'title': '컴퓨터구조 책삽니다', 'text': '표지에 컴퓨터구조 및 설계 써있고 5판 한글판 중고 2만원에삽니다\nPatterson , Hennessy 저자 입니다', 'category_id': 5, 'is_verified': None, 'possible_category_id': 5, 'probs_category_0': 4.4144e-06, 'probs_category_1': 0.000107299, 'probs_category_2': 4.80381e-06, 'probs_category_3': 0.000145806, 'probs_category_4': 0.000231803, 'probs_category_5': 0.998857, 'probs_category_6': 0.000176001, 'probs_category_7': 8.05743e-05, 'probs_category_8': 6.70068e-05, 'probs_category_9': 5.84376e-05, 'probs_category_10': 2.52188e-05, 'probs_category_11': 0.000180229, 'probs_category_12': 3.57415e-05, 'probs_category_13': 2.531e-05}
# {'id': 18, 'article_id': 21485924, 'title': '오늘 영화의 이해 수업', 'text': '영화의 이해 유양근 교수님 수업을 못가서 그런데 혹시 교재같은거나 해오라고 하신거 있나요?! ㅜㅜ', 'category_id': 6, 'is_verified': None, 'possible_category_id': 6, 'probs_category_0': 0.000703323, 'probs_category_1': 0.000159101, 'probs_category_2': 0.00032507, 'probs_category_3': 0.000294797, 'probs_category_4': 0.00038797, 'probs_category_5': 0.000761921, 'probs_category_6': 0.991134, 'probs_category_7': 0.00446594, 'probs_category_8': 0.000206625, 'probs_category_9': 4.75732e-05, 'probs_category_10': 0.000245989, 'probs_category_11': 0.000635507, 'probs_category_12': 0.000344973, 'probs_category_13': 0.000287296}
# {'id': 19, 'article_id': 21485950, 'title': '초급일본어', 'text': '전유나 초급일본어 책필요한가요?', 'category_id': 6, 'is_verified': None, 'possible_category_id': 6, 'probs_category_0': 0.000543147, 'probs_category_1': 0.000131889, 'probs_category_2': 0.000173995, 'probs_category_3': 0.000162129, 'probs_category_4': 0.00021279, 'probs_category_5': 0.000695406, 'probs_category_6': 0.99551, 'probs_category_7': 0.00166557, 'probs_category_8': 9.81723e-05, 'probs_category_9': 2.50136e-05, 'probs_category_10': 8.85989e-05, 'probs_category_11': 0.000397834, 'probs_category_12': 0.000178661, 'probs_category_13': 0.00011694}
# {'id': 20, 'article_id': 21487104, 'title': '나 진짜 어릴 때부터 궁금하던 건데 알려줄 사람', 'text': '버스 안에서 제자리 비행하고 있는 파리는\n버스가 앞으로 움직이면 버스 뒷자석에 부딪혀야 하자나...\n근데 왜 안 부딪혀', 'category_id': None, 'is_verified': None, 'possible_category_id': 11, 'probs_category_0': 0.00921202, 'probs_category_1': 0.000177916, 'probs_category_2': 6.24689e-05, 'probs_category_3': 0.0292339, 'probs_category_4': 0.000251957, 'probs_category_5': 0.000417821, 'probs_category_6': 0.000263243, 'probs_category_7': 0.00189909, 'probs_category_8': 0.000237188, 'probs_category_9': 0.119503, 'probs_category_10': 0.00102695, 'probs_category_11': 0.831288, 'probs_category_12': 0.00607691, 'probs_category_13': 0.000350038}

# %%
# 데이터 전처리 함수 정의

normal_pattern = re.compile(r'[^ .,?!/@$%~％·∼()\x00-\x7Fㄱ-ㅣ가-힣]+')
url_pattern = re.compile(r'https?:\/\/(www\.)?[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)')

def preprocess(value):
    value = normal_pattern.sub(' ', value)
    value = emoji.replace_emoji(value, replace='')
    value = url_pattern.sub('', value)
    value = repeat_normalize(value, num_repeats=2)
    value = value.strip()
    return value

# %%
# 데이터 전처리

contents = [preprocess(article['title'] + ' ' + article['text']) for article in tqdm(original_articles)]
# Out:
# 100%|██████████| 299314/299314 [00:10<00:00, 28481.40it/s]

# %%
# 전처리된 데이터의 일부를 출력

for content in contents[:20]:
    print(content)
# Out:
# 어제 비마관 화장실에서 핸드폰 찾아주신분! 제가 경황이 없어서 감사하다고도 못 했네요. 정말 감사합니다!!!
# 클럽좋아하시는분 계세요~? 남자 신입생인데 주말에갈려하는데 같이가실분 괌
# 조은문화사 몇시에 보통 열리나요?? 1교시 수업 책 찾아야되서
# 전공수업듣는데 복학한거처럼 보이는 형이 열심히는 하시던데 뭔가 군대갔다고오고 모든걸 까먹은 자기를 자책하듯이 수업듣는걸 보고 나도 3년후에 저러겠구나 싶더라... ㅠㅠ
# 정문에 있는 인쇄집들 몇시까지 하는지 아시나요? 9시 넘어야 갈수있을거 같은데 열어 있을지..
# 이런사람들 많나? 신입생 새터때 번호교환하고 학교서 인사만좀 하는사이였다가 연락 한 번도 안하고 군대가고 카톡친추는 되어있어서 누군지는 알고 복학하고 오니 서로 얼굴은아는데 인사하기도 민망하고 껄끄러운사이 너무 불편하다 엮일일 없으면 상관없는데 자꾸 마주치면 괜히 불편함
# 해상도! UHD 즉 4K면 코딩할때 글자 잘 안보이겠죠? 그냥 FHD면 충분?
# 문화유목시대 교재뭔가요 정정기간때 신청해서 잘 모르겠어요. ㅠㅠ 계획서보니까 고른다고하는데 뭐에요?
# 난 멋있어 멋있어
# 내일 공강이다 불기둥 같은 월화수를 마치고 목금이 오긴 왔네...
# 힙동 들어가고싶긴한데 커버밖에 못하고 리얼 힙찔이라 엄두가안난다
# 바람지원했는데요 아직 연락이 안왔는데 다들 안온건가요!?
# 전자회로실험 파형이 물결처럼 나와야하는데 왜 난 일자로 나오지???;; 이번에 복학해서 실험들으려는데 그냥 예비는 똑같이 따라하면 되는거 아닌가? 왜 일자로만 나와....
# 전자회로실험 파형이 물결처럼 나와야하는데 왜 난 일자로 나오지???;; 이번에 복학해서 실험들으려는데 그냥 예비는 똑같이 따라하면 되는거 아닌가? 왜 일자로만 나와.... 이건 회로인데 뭐가 잘못된거지요????;;
# 이쯤에서 질문 전공서적 (2 3 4학년 상관없음) 1. 새책산다 2. 중고로 산다 3. 제본뜬다 4. 물려받는다 새책사거나 중고사신분 또 질문 a. 중고로 판다 b. 그냥 가지고 있는다 c. 물려준다
# 화공과 유기화학1수업 책 : 스미스 유기화학 번역판 샀는데 원서없으면 시험보기힘든가요?
# 컴퓨터구조 책삽니다 표지에 컴퓨터구조 및 설계 써있고 5판 한글판 중고 2만원에삽니다 Patterson , Hennessy 저자 입니다
# 오늘 영화의 이해 수업 영화의 이해 유양근 교수님 수업을 못가서 그런데 혹시 교재같은거나 해오라고 하신거 있나요?! ㅜㅜ
# 초급일본어 전유나 초급일본어 책필요한가요?
# 나 진짜 어릴 때부터 궁금하던 건데 알려줄 사람 버스 안에서 제자리 비행하고 있는 파리는 버스가 앞으로 움직이면 버스 뒷자석에 부딪혀야 하자나... 근데 왜 안 부딪혀

# %%
# 토크나이저 로드

tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_ID)

print('Original:', contents[0])
print('Tokenized:', tokenizer.tokenize(contents[0]))
# Out:
# Original: 어제 비마관 화장실에서 핸드폰 찾아주신분! 제가 경황이 없어서 감사하다고도 못 했네요. 정말 감사합니다!!!
# Tokenized: ['어제', '비', '##마', '##관', '화장실', '##에서', '핸드폰', '찾아', '##주신', '##분', '!', '제가', '경', '##황', '##이', '없어서', '감사', '##하다고', '##도', '못', '했네요', '.', '정말', '감사합니다', '!', '!', '!']

# %%
# 모델 로드

model = AutoModelForSequenceClassification.from_pretrained(MODEL_ID, num_labels=NUM_LABELS)
model.to(device)
# Out:
# ElectraForSequenceClassification(
#   (electra): ElectraModel(
#     (embeddings): ElectraEmbeddings(
#       (word_embeddings): Embedding(54343, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): ElectraEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): ElectraClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): GELUActivation()
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=14, bias=True)
#   )
# )

# %%
# 모델 세부 정보 수정

model.resize_token_embeddings(len(tokenizer))
# Out:
# Embedding(54343, 768, padding_idx=0)

# %%
# 텍스트 인코딩 및 데이터셋 생성

encodings = tokenizer(
    contents,
    padding=True,
    truncation=True,
    return_tensors='pt',
    max_length=MAX_LENGTH
)
dataset = torch.utils.data.TensorDataset(
    torch.tensor(encodings['input_ids']),
    torch.tensor(encodings['attention_mask'])
)
dataloader = torch.utils.data.DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# /tmp/ipykernel_929215/3188963195.py:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(encodings['input_ids']),
# /tmp/ipykernel_929215/3188963195.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(encodings['attention_mask'])

# %%
# 예측 수행

columns = [
    'id',
    'title',
    'text',
    'category_id',
    'possible_category_id',
    'predicted_category_id',
    *[f'probs_category_{i}' for i in range(NUM_LABELS)]
]
df_results = pd.DataFrame(original_articles, columns=columns)
df_results['category_id'] = df_results['category_id'].fillna(-1).astype(int)

for i, batch in enumerate(tqdm(dataloader, desc='Predicting')):
    input_ids = batch[0].to(device)
    attention_mask = batch[1].to(device)

    with torch.no_grad():
        outputs = model(input_ids, attention_mask=attention_mask)
        logits = outputs.logits
        predictions = torch.argmax(logits, dim=1)
        probabilities = torch.softmax(logits, dim=1)

    start_index = i * BATCH_SIZE
    end_index = start_index + BATCH_SIZE

    df_results.loc[start_index:end_index - 1, 'predicted_category_id'] = predictions.tolist()
    for j in range(NUM_LABELS):
        df_results.loc[start_index:end_index - 1, f'probs_category_{j}'] = probabilities[:, j].tolist()

df_results['predicted_category_id'] = df_results['predicted_category_id'].astype(int)

print('Prediction completed.')
# Out:
# Predicting: 100%|██████████| 9354/9354 [18:23<00:00,  8.48it/s]
# Prediction completed.

# %%
# 예측 결과의 일부를 출력

df_results.head(20)
# Out:
#     id                                    title  \
# 0    1                  어제 비마관 화장실에서 핸드폰 찾아주신분!
# 1    2                           클럽좋아하시는분 계세요~?
# 2    3                      조은문화사 몇시에 보통 열리나요??
# 3    4                                  전공수업듣는데
# 4    5               정문에 있는 인쇄집들 몇시까지 하는지 아시나요?
# 5    6                                이런사람들 많나?
# 6    7                                     해상도!
# 7    8                             문화유목시대 교재뭔가요
# 8    9                                        난
# 9   10                                  내일 공강이다
# 10  11                              힙동 들어가고싶긴한데
# 11  12                                 바람지원했는데요
# 12  13  전자회로실험 파형이 물결처럼 나와야하는데 왜 난 일자로 나오지???;;
# 13  14  전자회로실험 파형이 물결처럼 나와야하는데 왜 난 일자로 나오지???;;
# 14  15                                  이쯤에서 질문
# 15  16                 화공과 유기화학1수업 책 : 스미스 유기화학
# 16  17                               컴퓨터구조 책삽니다
# 17  18                             오늘 영화의 이해 수업
# 18  19                                    초급일본어
# 19  20               나 진짜 어릴 때부터 궁금하던 건데 알려줄 사람
#
#                                                  text  category_id  \
# 0               제가 경황이 없어서 감사하다고도 못 했네요.\n정말 감사합니다!!!            9
# 1                           남자 신입생인데 주말에갈려하는데 같이가실분 괌           -1
# 2                                      1교시 수업 책 찾아야되서            7
# 3   복학한거처럼 보이는 형이 열심히는 하시던데 뭔가 군대갔다고오고 모든걸 까먹은 자기를...            4
# 4                          9시 넘어야 갈수있을거 같은데\n열어 있을지..            7
# 5   신입생 새터때 번호교환하고 학교서 인사만좀 하는사이였다가 연락 한 번도 안하고 군대...           -1
# 6             UHD 즉 4K면 코딩할때 글자 잘 안보이겠죠?\n그냥 FHD면 충분?           -1
# 7          정정기간때 신청해서 잘 모르겠어요. ㅠㅠ 계획서보니까 고른다고하는데 뭐에요?            6
# 8                                             멋있어 멋있어           -1
# 9                        불기둥 같은 월화수를 마치고 목금이 오긴 왔네...           -1
# 10                           커버밖에 못하고\n리얼 힙찔이라 엄두가안난다           -1
# 11                             아직 연락이 안왔는데 다들 안온건가요!?           -1
# 12  이번에 복학해서 실험들으려는데 그냥 예비는 똑같이 따라하면 되는거 아닌가?\n왜 일...            5
# 13  이번에 복학해서 실험들으려는데 그냥 예비는 똑같이 따라하면 되는거 아닌가?\n왜 일...            5
# 14  전공서적 (2 3 4학년 상관없음)\n1. 새책산다\n2. 중고로 산다\n3. 제본...           -1
# 15                            번역판 샀는데 원서없으면 시험보기힘든가요?           -1
# 16  표지에 컴퓨터구조 및 설계 써있고 5판 한글판 중고 2만원에삽니다\nPatterso...            5
# 17  영화의 이해 유양근 교수님 수업을 못가서 그런데 혹시 교재같은거나 해오라고 하신거 ...            6
# 18                                  전유나 초급일본어 책필요한가요?            6
# 19  버스 안에서 제자리 비행하고 있는 파리는\n버스가 앞으로 움직이면 버스 뒷자석에 부...           -1
#
#     possible_category_id  predicted_category_id  probs_category_0  \
# 0                      9                      9          0.002883
# 1                     11                     11          0.000897
# 2                      7                      7          0.000016
# 3                      4                      4          0.000523
# 4                      7                      7          0.000019
# 5                      3                     13          0.001064
# 6                      9                      9          0.000441
# 7                      6                      6          0.000612
# 8                     11                      0          0.922669
# 9                      3                      3          0.003932
# 10                    11                     11          0.000616
# 11                     9                      9          0.012468
# 12                     5                      5          0.000028
# 13                     5                      5          0.000029
# 14                     4                      4          0.006709
# 15                     5                      5          0.000030
# 16                     5                      5          0.000029
# 17                     6                      6          0.000362
# 18                     6                      6          0.000314
# 19                    11                      9          0.014550
#
#     probs_category_1  probs_category_2  probs_category_3  probs_category_4  \
# 0           0.000207          0.000261          0.000065          0.000048
# 1           0.000141          0.000020          0.000896          0.000102
# 2           0.000081          0.000247          0.000533          0.000131
# 3           0.000760          0.000121          0.000322          0.995925
# 4           0.000097          0.000265          0.000298          0.000118
# 5           0.000254          0.000046          0.001164          0.000768
# 6           0.000231          0.000124          0.000054          0.000049
# 7           0.000707          0.001070          0.001010          0.003734
# 8           0.000792          0.000176          0.001423          0.001028
# 9           0.000207          0.000153          0.982244          0.003825
# 10          0.000124          0.000015          0.000696          0.000099
# 11          0.002950          0.003482          0.010188          0.001049
# 12          0.000172          0.000047          0.000200          0.000332
# 13          0.000166          0.000048          0.000194          0.000365
# 14          0.019669          0.000748          0.000734          0.947741
# 15          0.000165          0.000051          0.000173          0.000278
# 16          0.000153          0.000053          0.000242          0.000325
# 17          0.000177          0.000206          0.000323          0.000242
# 18          0.000176          0.000195          0.000223          0.000207
# 19          0.000705          0.000323          0.000786          0.000376
#
#     probs_category_5  probs_category_6  probs_category_7  probs_category_8  \
# 0           0.000010          0.000041          0.000439          0.000086
# 1           0.000106          0.000238          0.000188          0.000436
# 2           0.000216          0.000043          0.997201          0.000025
# 3           0.000387          0.000199          0.000302          0.000672
# 4           0.000243          0.000046          0.996965          0.000024
# 5           0.000350          0.000237          0.002413          0.006908
# 6           0.000015          0.000043          0.000351          0.000152
# 7           0.002242          0.987481          0.001471          0.000533
# 8           0.000322          0.001651          0.000132          0.000615
# 9           0.000987          0.001962          0.000505          0.001284
# 10          0.000147          0.000175          0.000109          0.000445
# 11          0.001141          0.010176          0.007376          0.002356
# 12          0.997612          0.000522          0.000499          0.000147
# 13          0.997575          0.000524          0.000495          0.000152
# 14          0.001924          0.001491          0.000528          0.010552
# 15          0.997677          0.000607          0.000432          0.000156
# 16          0.997395          0.000499          0.000649          0.000163
# 17          0.001153          0.994885          0.001092          0.000310
# 18          0.001309          0.995402          0.000726          0.000264
# 19          0.000081          0.000197          0.002823          0.000247
#
#     probs_category_9  probs_category_10  probs_category_11  probs_category_12  \
# 0           0.994373           0.000607           0.000402           0.000306
# 1           0.002561           0.000734           0.981399           0.011821
# 2           0.000252           0.000985           0.000078           0.000018
# 3           0.000103           0.000200           0.000112           0.000142
# 4           0.000350           0.001287           0.000080           0.000019
# 5           0.010115           0.001386           0.005779           0.015176
# 6           0.997291           0.000285           0.000461           0.000248
# 7           0.000277           0.000201           0.000278           0.000314
# 8           0.002458           0.000990           0.036559           0.030160
# 9           0.000238           0.000174           0.003669           0.000677
# 10          0.000815           0.000300           0.994003           0.002153
# 11          0.853191           0.001472           0.089286           0.004195
# 12          0.000071           0.000089           0.000134           0.000082
# 13          0.000074           0.000093           0.000133           0.000084
# 14          0.004713           0.000552           0.000608           0.002836
# 15          0.000068           0.000089           0.000125           0.000082
# 16          0.000078           0.000110           0.000141           0.000086
# 17          0.000263           0.000186           0.000349           0.000366
# 18          0.000258           0.000151           0.000368           0.000346
# 19          0.974450           0.000870           0.002695           0.001201
#
#     probs_category_13
# 0            0.000274
# 1            0.000462
# 2            0.000173
# 3            0.000232
# 4            0.000188
# 5            0.954339
# 6            0.000255
# 7            0.000069
# 8            0.001026
# 9            0.000142
# 10           0.000302
# 11           0.000670
# 12           0.000066
# 13           0.000069
# 14           0.001195
# 15           0.000068
# 16           0.000077
# 17           0.000084
# 18           0.000062
# 19           0.000696

# %%
# 평가 지표 계산 함수 정의

def calculate_metrics(true_labels, predicted_labels):
    acc = accuracy_score(true_labels, predicted_labels)
    prec = precision_score(true_labels, predicted_labels, average=METRIC_AVERAGE, zero_division=METRIC_ZERO_DIVISION)
    rec = recall_score(true_labels, predicted_labels, average=METRIC_AVERAGE, zero_division=METRIC_ZERO_DIVISION)
    f1 = f1_score(true_labels, predicted_labels, average=METRIC_AVERAGE, zero_division=METRIC_ZERO_DIVISION)

    return acc, prec, rec, f1

# %%
# 평가 지표 출력

labels = []
predictions = []

for i in range(len(df_results)):
    if df_results.loc[i, 'category_id'] != -1:
        labels.append(df_results.loc[i, 'category_id'])
        predictions.append(df_results.loc[i, 'predicted_category_id'])

acc, prec, rec, f1 = calculate_metrics(labels, predictions)

print(f'Accuracy: {acc:.4f}')
print(f'Precision: {prec:.4f}')
print(f'Recall: {rec:.4f}')
print(f'F1 Score: {f1:.4f}')
# Out:
# Accuracy: 0.9904
# Precision: 0.9905
# Recall: 0.9904
# F1 Score: 0.9905

# %%
# 예측 결과의 비율을 출력

threshold_counts = [0] * NUM_LABELS
total_count = len(df_results)

for i in range(NUM_LABELS):
    column_name = f'probs_category_{i}'
    threshold_counts[i] = (df_results[column_name] > THRESHOLD).sum()

threshold_percentages = [(count / total_count * 100) for count in threshold_counts]

for i in range(NUM_LABELS):
    print(f'{CATEGORIES[i]} ({i}): {threshold_counts[i]} ({threshold_percentages[i]:.2f}%)')

plt.figure(figsize=(12, 8))
plt.bar(range(NUM_LABELS), threshold_counts)
for i, count in enumerate(threshold_counts):
    plt.text(i, count + 0.1, f'{count} ({threshold_percentages[i]:.2f}%)', ha='center')
plt.xlabel(f'Threshold ({THRESHOLD})')
plt.ylabel('Count')
plt.xticks(range(NUM_LABELS))
plt.title('Distribution of Predictions Above Threshold by Category')
plt.show()
# Out:
# 자유 (0): 42133 (14.08%)
# 학사 (1): 23644 (7.90%)
# 장학 · 행정 (2): 12688 (4.24%)
# 학교생활 (3): 12181 (4.07%)
# 수업 (4): 29874 (9.98%)
# 수업/이과 (5): 40882 (13.66%)
# 수업/문과 (6): 23935 (8.00%)
# 캠퍼스 (7): 23597 (7.88%)
# 취업 · 진로 (8): 15374 (5.14%)
# 일상생활 (9): 31629 (10.57%)
# 음식점 · 카페 (10): 4689 (1.57%)
# 취미 · 여가 (11): 17283 (5.77%)
# 인간관계 (12): 7389 (2.47%)
# 병역 (13): 6269 (2.09%)

# %%
# 기존 카테고리와 예측 카테고리가 다른 경우의 비율을 출력

changed_counts = [0] * NUM_LABELS
total_count = len(df_results)

for i in range(total_count):
    possible_category_id = df_results.loc[i, 'possible_category_id']
    predicted_category_id = df_results.loc[i, 'predicted_category_id']
    if possible_category_id != predicted_category_id:
        changed_counts[possible_category_id] += 1

changed_percentages = [(count / total_count * 100) for count in changed_counts]
total_changed_count = sum(changed_counts)
total_changed_percentage = total_changed_count / total_count * 100

print(f'Total changed count: {total_changed_count} ({total_changed_percentage:.2f}%)')
for i in range(NUM_LABELS):
    print(f'{CATEGORIES[i]} [{i}]: {changed_counts[i]} ({changed_percentages[i]:.2f}%)')

plt.figure(figsize=(12, 8))
plt.bar(range(NUM_LABELS), changed_counts)
for i, count in enumerate(changed_counts):
    plt.text(i, count + 0.1, f'{count} ({changed_percentages[i]:.2f}%)', ha='center')
plt.xlabel('Category')
plt.ylabel('Changed Count')
plt.xticks(range(NUM_LABELS))
plt.title('Distribution of Changed Predictions by Category')
plt.tight_layout()
plt.show()
# Out:
# Total changed count: 89571 (29.93%)
# 자유 [0]: 9134 (3.05%)
# 학사 [1]: 4544 (1.52%)
# 장학 · 행정 [2]: 587 (0.20%)
# 학교생활 [3]: 9238 (3.09%)
# 수업 [4]: 4154 (1.39%)
# 수업/이과 [5]: 10681 (3.57%)
# 수업/문과 [6]: 8910 (2.98%)
# 캠퍼스 [7]: 3682 (1.23%)
# 취업 · 진로 [8]: 4883 (1.63%)
# 일상생활 [9]: 10792 (3.61%)
# 음식점 · 카페 [10]: 633 (0.21%)
# 취미 · 여가 [11]: 20166 (6.74%)
# 인간관계 [12]: 1684 (0.56%)
# 병역 [13]: 483 (0.16%)

# %%
# 예측 결과를 DB에 저장

connection = db.get_connection()
cursor = connection.cursor()

sql_template = f'''
    INSERT INTO {TABLE_NAME} (id, possible_category_id, {{columns}})
    VALUES (%s, %s, {{placeholders}})
    ON DUPLICATE KEY UPDATE
        possible_category_id = VALUES(possible_category_id),
        {{updates}}
'''

columns = ', '.join([f'probs_category_{i}' for i in range(NUM_LABELS)])
placeholders = ', '.join(['%s' for _ in range(NUM_LABELS)])
updates = ', '.join([f'probs_category_{i} = VALUES(probs_category_{i})' for i in range(NUM_LABELS)])

sql = sql_template.format(columns=columns, placeholders=placeholders, updates=updates)
values = [(row['id'], row['predicted_category_id'],) + tuple(row[f'probs_category_{i}'] for i in range(NUM_LABELS)) for _, row in df_results.iterrows()]

cursor.executemany(sql, values)
connection.commit()

cursor.close()
db.close_connection()
# Out:
# Connected to DB successfully.
