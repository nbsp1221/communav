# %%
# 다른 경로에 있는 모듈을 가져오기 위해 절대 경로 추가

import os
import sys

root = os.path.join(os.path.abspath(os.getcwd()), '..', '..')
root = os.path.normpath(root)

if root not in sys.path:
    sys.path.insert(0, root)

# %%
# 필요한 라이브러리 로드

import emoji
import json
import matplotlib.pyplot as plt
import os
import pandas as pd
import re
import torch
from communav.utils import db
from sklearn.metrics import accuracy_score, fbeta_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from soynlp.normalizer import repeat_normalize
from tqdm import tqdm
from transformers import AutoModelForSequenceClassification, AutoTokenizer, get_linear_schedule_with_warmup
# Out:
# /tmp/ipykernel_335707/1026082369.py:7: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# 카테고리 정의

CATEGORIES = {
    0: '자유',
    1: '학사',
    2: '장학 · 행정',
    3: '학교생활',
    4: '수업',
    5: '수업/이과',
    6: '수업/문과',
    7: '캠퍼스',
    8: '취업 · 진로',
    9: '일상생활',
    10: '음식점 · 카페',
    11: '취미 · 여가',
    12: '인간관계',
    13: '병역'
}

# %%
# 파라미터 설정

TABLE_NAME = 'everytime_article_dataset_v1'
MODEL_ID = '/mnt/data01/communav/model-epoch-10-0.9659'
NUM_LABELS = len(CATEGORIES)
MAX_LENGTH = 128
BATCH_SIZE = 32
THRESHOLD = 0.9

# %%
# 커뮤니티 게시글 데이터 로드

connection = db.get_connection()
cursor = connection.cursor()

cursor.execute(f'''
    SELECT * FROM {TABLE_NAME}
''')
original_articles = cursor.fetchall()
print(f'Loaded {len(original_articles)} articles.')

cursor.close()
db.close_connection()
# Out:
# Connected to DB successfully.
# Loaded 299314 articles.

# %%
# 가져온 데이터의 일부를 출력

for article in original_articles[:20]:
    print(article)
# Out:
# {'id': 1, 'article_id': 21479637, 'title': '어제 비마관 화장실에서 핸드폰 찾아주신분!', 'text': '제가 경황이 없어서 감사하다고도 못 했네요.\n정말 감사합니다!!!', 'category_id': 9, 'is_verified': 1, 'probs_category_0': 0.000256669, 'probs_category_1': 0.000108048, 'probs_category_2': 0.00012192, 'probs_category_3': 0.000155984, 'probs_category_4': 0.000135768, 'probs_category_5': 0.000489102, 'probs_category_6': 4.08579e-05, 'probs_category_7': 0.000247165, 'probs_category_8': 0.000313037, 'probs_category_9': 0.99616, 'probs_category_10': 0.00037841, 'probs_category_11': 0.000841255, 'probs_category_12': 0.000555584, 'probs_category_13': 0.000196455}
# {'id': 2, 'article_id': 21480514, 'title': '클럽좋아하시는분 계세요~?', 'text': '남자 신입생인데 주말에갈려하는데 같이가실분 괌', 'category_id': None, 'is_verified': None, 'probs_category_0': 0.00624936, 'probs_category_1': 0.000424744, 'probs_category_2': 0.0011219, 'probs_category_3': 0.100194, 'probs_category_4': 0.000872033, 'probs_category_5': 0.00218386, 'probs_category_6': 0.00173036, 'probs_category_7': 0.0350595, 'probs_category_8': 0.000796891, 'probs_category_9': 0.00944325, 'probs_category_10': 0.00730313, 'probs_category_11': 0.815459, 'probs_category_12': 0.0140426, 'probs_category_13': 0.0051191}
# {'id': 3, 'article_id': 21480639, 'title': '조은문화사 몇시에 보통 열리나요??', 'text': '1교시 수업 책 찾아야되서', 'category_id': 7, 'is_verified': 1, 'probs_category_0': 0.000283315, 'probs_category_1': 0.000808695, 'probs_category_2': 0.000252487, 'probs_category_3': 0.00262766, 'probs_category_4': 0.000542025, 'probs_category_5': 0.00202448, 'probs_category_6': 0.991084, 'probs_category_7': 0.000924206, 'probs_category_8': 0.000216003, 'probs_category_9': 7.2068e-05, 'probs_category_10': 0.000629439, 'probs_category_11': 0.000281596, 'probs_category_12': 0.000194085, 'probs_category_13': 6.03953e-05}
# {'id': 4, 'article_id': 21481049, 'title': '전공수업듣는데', 'text': '복학한거처럼 보이는 형이 열심히는 하시던데 뭔가 군대갔다고오고 모든걸 까먹은 자기를 자책하듯이 수업듣는걸 보고 나도 3년후에 저러겠구나 싶더라... ㅠㅠ', 'category_id': 4, 'is_verified': None, 'probs_category_0': 0.000183049, 'probs_category_1': 0.000279705, 'probs_category_2': 0.000134394, 'probs_category_3': 0.000409938, 'probs_category_4': 0.992246, 'probs_category_5': 0.00100219, 'probs_category_6': 0.00105786, 'probs_category_7': 0.000163983, 'probs_category_8': 0.00133312, 'probs_category_9': 0.000513091, 'probs_category_10': 0.00118213, 'probs_category_11': 0.00103685, 'probs_category_12': 0.000360694, 'probs_category_13': 9.67951e-05}
# {'id': 5, 'article_id': 21481575, 'title': '정문에 있는 인쇄집들 몇시까지 하는지 아시나요?', 'text': '9시 넘어야 갈수있을거 같은데\n열어 있을지..', 'category_id': 7, 'is_verified': 1, 'probs_category_0': 0.000441077, 'probs_category_1': 0.00054343, 'probs_category_2': 0.000565587, 'probs_category_3': 0.000648492, 'probs_category_4': 0.000746164, 'probs_category_5': 0.000348498, 'probs_category_6': 0.0011735, 'probs_category_7': 0.587603, 'probs_category_8': 0.000856812, 'probs_category_9': 0.00133048, 'probs_category_10': 0.403598, 'probs_category_11': 0.00111315, 'probs_category_12': 0.000442481, 'probs_category_13': 0.000589154}
# {'id': 6, 'article_id': 21482091, 'title': '이런사람들 많나?', 'text': '신입생 새터때 번호교환하고 학교서 인사만좀 하는사이였다가 연락 한 번도 안하고 군대가고 카톡친추는 되어있어서 누군지는 알고 복학하고 오니 서로 얼굴은아는데 인사하기도 민망하고 껄끄러운사이 너무 불편하다 엮일일 없으면 상관없는데 자꾸 마주치면 괜히 불편함', 'category_id': None, 'is_verified': None, 'probs_category_0': 0.00351748, 'probs_category_1': 0.00125521, 'probs_category_2': 0.000292611, 'probs_category_3': 0.974211, 'probs_category_4': 0.00085922, 'probs_category_5': 0.000364747, 'probs_category_6': 0.000622451, 'probs_category_7': 0.000621499, 'probs_category_8': 0.00269825, 'probs_category_9': 0.00296045, 'probs_category_10': 0.000568575, 'probs_category_11': 0.00404954, 'probs_category_12': 0.00576932, 'probs_category_13': 0.00220919}
# {'id': 7, 'article_id': 21482097, 'title': '해상도!', 'text': 'UHD 즉 4K면 코딩할때 글자 잘 안보이겠죠?\n그냥 FHD면 충분?', 'category_id': None, 'is_verified': None, 'probs_category_0': 0.000901915, 'probs_category_1': 0.000232293, 'probs_category_2': 0.000604299, 'probs_category_3': 0.000877528, 'probs_category_4': 0.00165632, 'probs_category_5': 0.0111445, 'probs_category_6': 0.00041818, 'probs_category_7': 0.00135209, 'probs_category_8': 0.00152667, 'probs_category_9': 0.855825, 'probs_category_10': 0.0025075, 'probs_category_11': 0.120918, 'probs_category_12': 0.00141762, 'probs_category_13': 0.00061768}
# {'id': 8, 'article_id': 21482121, 'title': '문화유목시대 교재뭔가요', 'text': '정정기간때 신청해서 잘 모르겠어요. ㅠㅠ 계획서보니까 고른다고하는데 뭐에요?', 'category_id': 6, 'is_verified': None, 'probs_category_0': 0.00027938, 'probs_category_1': 0.00138421, 'probs_category_2': 0.000307664, 'probs_category_3': 0.00178348, 'probs_category_4': 0.000510128, 'probs_category_5': 0.00226401, 'probs_category_6': 0.991812, 'probs_category_7': 0.000601002, 'probs_category_8': 0.000228548, 'probs_category_9': 6.44611e-05, 'probs_category_10': 0.00039932, 'probs_category_11': 0.000137162, 'probs_category_12': 0.000166686, 'probs_category_13': 6.16845e-05}
# {'id': 9, 'article_id': 21482730, 'title': '난', 'text': '멋있어 멋있어', 'category_id': None, 'is_verified': None, 'probs_category_0': 0
 진짜 어릴 때부터 궁금하던 건데 알려줄 사람', 'text': '버스 안에서 제자리 비행하고 있는 파리는\n버스가 앞으로 움직이면 버스 뒷자석에 부딪혀야 하자나...\n근데 왜 안 부딪혀', 'category_id': None, 'is_verified': None, 'probs_category_0': 0.00244054, 'probs_category_1': 0.000121333, 'probs_category_2': 0.000384879, 'probs_category_3': 0.0106814, 'probs_category_4': 0.00069196, 'probs_category_5': 0.000652576, 'probs_category_6': 0.000434613, 'probs_category_7': 0.00216424, 'probs_category_8': 0.000717707, 'probs_category_9': 0.0210774, 'probs_category_10': 0.00309964, 'probs_category_11': 0.945898, 'probs_category_12': 0.00922916, 'probs_category_13': 0.00240666}

# %%
# 데이터 전처리 함수 정의

normal_pattern = re.compile(r'[^ .,?!/@$%~％·∼()\x00-\x7Fㄱ-ㅣ가-힣]+')
url_pattern = re.compile(r'https?:\/\/(www\.)?[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)')

def preprocess(value):
    value = normal_pattern.sub(' ', value)
    value = emoji.replace_emoji(value, replace='')
    value = url_pattern.sub('', value)
    value = repeat_normalize(value, num_repeats=2)
    value = value.strip()
    return value

# %%
# 데이터 전처리

contents = [preprocess(article['title'] + ' ' + article['text']) for article in original_articles]

# %%
# 전처리된 데이터의 일부를 출력

for content in contents[:20]:
    print(content)
# Out:
# 어제 비마관 화장실에서 핸드폰 찾아주신분! 제가 경황이 없어서 감사하다고도 못 했네요. 정말 감사합니다!!!
# 클럽좋아하시는분 계세요~? 남자 신입생인데 주말에갈려하는데 같이가실분 괌
# 조은문화사 몇시에 보통 열리나요?? 1교시 수업 책 찾아야되서
# 전공수업듣는데 복학한거처럼 보이는 형이 열심히는 하시던데 뭔가 군대갔다고오고 모든걸 까먹은 자기를 자책하듯이 수업듣는걸 보고 나도 3년후에 저러겠구나 싶더라... ㅠㅠ
# 정문에 있는 인쇄집들 몇시까지 하는지 아시나요? 9시 넘어야 갈수있을거 같은데 열어 있을지..
# 이런사람들 많나? 신입생 새터때 번호교환하고 학교서 인사만좀 하는사이였다가 연락 한 번도 안하고 군대가고 카톡친추는 되어있어서 누군지는 알고 복학하고 오니 서로 얼굴은아는데 인사하기도 민망하고 껄끄러운사이 너무 불편하다 엮일일 없으면 상관없는데 자꾸 마주치면 괜히 불편함
# 해상도! UHD 즉 4K면 코딩할때 글자 잘 안보이겠죠? 그냥 FHD면 충분?
# 문화유목시대 교재뭔가요 정정기간때 신청해서 잘 모르겠어요. ㅠㅠ 계획서보니까 고른다고하는데 뭐에요?
# 난 멋있어 멋있어
# 내일 공강이다 불기둥 같은 월화수를 마치고 목금이 오긴 왔네...
# 힙동 들어가고싶긴한데 커버밖에 못하고 리얼 힙찔이라 엄두가안난다
# 바람지원했는데요 아직 연락이 안왔는데 다들 안온건가요!?
# 전자회로실험 파형이 물결처럼 나와야하는데 왜 난 일자로 나오지???;; 이번에 복학해서 실험들으려는데 그냥 예비는 똑같이 따라하면 되는거 아닌가? 왜 일자로만 나와....
# 전자회로실험 파형이 물결처럼 나와야하는데 왜 난 일자로 나오지???;; 이번에 복학해서 실험들으려는데 그냥 예비는 똑같이 따라하면 되는거 아닌가? 왜 일자로만 나와.... 이건 회로인데 뭐가 잘못된거지요????;;
# 이쯤에서 질문 전공서적 (2 3 4학년 상관없음) 1. 새책산다 2. 중고로 산다 3. 제본뜬다 4. 물려받는다 새책사거나 중고사신분 또 질문 a. 중고로 판다 b. 그냥 가지고 있는다 c. 물려준다
# 화공과 유기화학1수업 책 : 스미스 유기화학 번역판 샀는데 원서없으면 시험보기힘든가요?
# 컴퓨터구조 책삽니다 표지에 컴퓨터구조 및 설계 써있고 5판 한글판 중고 2만원에삽니다 Patterson , Hennessy 저자 입니다
# 오늘 영화의 이해 수업 영화의 이해 유양근 교수님 수업을 못가서 그런데 혹시 교재같은거나 해오라고 하신거 있나요?! ㅜㅜ
# 초급일본어 전유나 초급일본어 책필요한가요?
# 나 진짜 어릴 때부터 궁금하던 건데 알려줄 사람 버스 안에서 제자리 비행하고 있는 파리는 버스가 앞으로 움직이면 버스 뒷자석에 부딪혀야 하자나... 근데 왜 안 부딪혀

# %%
# 토크나이저 로드

tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)

print('Original:', contents[0])
print('Tokenized:', tokenizer.tokenize(contents[0]))
# Out:
# Original: 어제 비마관 화장실에서 핸드폰 찾아주신분! 제가 경황이 없어서 감사하다고도 못 했네요. 정말 감사합니다!!!
# Tokenized: ['어제', '비', '##마', '##관', '화장실', '##에서', '핸드폰', '찾아', '##주신', '##분', '!', '제가', '경', '##황', '##이', '없어서', '감사', '##하다고', '##도', '못', '했네요', '.', '정말', '감사합니다', '!', '!', '!']

# %%
# 모델 로드

if torch.cuda.is_available():
    device = torch.device('cuda')
    print('There are %d GPU(s) available.' % torch.cuda.device_count())
    print('We will use the GPU:', torch.cuda.get_device_name(0))
else:
    device = torch.device('cpu')
    print('No GPU available, using the CPU instead.')

model = AutoModelForSequenceClassification.from_pretrained(MODEL_ID, num_labels=NUM_LABELS)
model.to(device)
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 3060 Ti
# ElectraForSequenceClassification(
#   (electra): ElectraModel(
#     (embeddings): ElectraEmbeddings(
#       (word_embeddings): Embedding(54343, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): ElectraEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): ElectraClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): GELUActivation()
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=14, bias=True)
#   )
# )

# %%
# 텍스트 인코딩 및 데이터셋 생성

encodings = tokenizer(
    contents,
    padding=True,
    truncation=True,
    return_tensors='pt',
    max_length=MAX_LENGTH
)
dataset = torch.utils.data.TensorDataset(
    torch.tensor(encodings['input_ids']),
    torch.tensor(encodings['attention_mask'])
)
dataloader = torch.utils.data.DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# /tmp/ipykernel_335707/3188963195.py:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(encodings['input_ids']),
# /tmp/ipykernel_335707/3188963195.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(encodings['attention_mask'])

# %%
# 예측 수행

category_columns = [f'probs_category_{i}' for i in range(NUM_LABELS)]
columns = ['id', 'title', 'text'] + category_columns
df_results = pd.DataFrame(original_articles, columns=columns)

for i, batch in enumerate(tqdm(dataloader, desc='Predicting')):
    input_ids = batch[0].to(device)
    attention_mask = batch[1].to(device)

    with torch.no_grad():
        outputs = model(input_ids, attention_mask=attention_mask)
        logits = outputs.logits
        probabilities = torch.softmax(logits, dim=1)

    start_index = i * BATCH_SIZE
    end_index = start_index + BATCH_SIZE

    for j in range(NUM_LABELS):
        df_results.loc[start_index:end_index - 1, f'probs_category_{j}'] = probabilities[:, j].tolist()

print('Prediction completed.')
# Out:
# Predicting: 100%|██████████| 9354/9354 [18:25<00:00,  8.46it/s]
# Prediction completed.

# %%
# 예측 결과의 일부를 출력

df_results.head(20)
# Out:
#     id                                    title  \
# 0    1                  어제 비마관 화장실에서 핸드폰 찾아주신분!
# 1    2                           클럽좋아하시는분 계세요~?
# 2    3                      조은문화사 몇시에 보통 열리나요??
# 3    4                                  전공수업듣는데
# 4    5               정문에 있는 인쇄집들 몇시까지 하는지 아시나요?
# 5    6                                이런사람들 많나?
# 6    7                                     해상도!
# 7    8                             문화유목시대 교재뭔가요
# 8    9                                        난
# 9   10                                  내일 공강이다
# 10  11                              힙동 들어가고싶긴한데
# 11  12                                 바람지원했는데요
# 12  13  전자회로실험 파형이 물결처럼 나와야하는데 왜 난 일자로 나오지???;;
# 13  14  전자회로실험 파형이 물결처럼 나와야하는데 왜 난 일자로 나오지???;;
# 14  15                                  이쯤에서 질문
# 15  16                 화공과 유기화학1수업 책 : 스미스 유기화학
# 16  17                               컴퓨터구조 책삽니다
# 17  18                             오늘 영화의 이해 수업
# 18  19                                    초급일본어
# 19  20               나 진짜 어릴 때부터 궁금하던 건데 알려줄 사람
#
#                                                  text  probs_category_0  \
# 0               제가 경황이 없어서 감사하다고도 못 했네요.\n정말 감사합니다!!!          0.077221
# 1                           남자 신입생인데 주말에갈려하는데 같이가실분 괌          0.001291
# 2                                      1교시 수업 책 찾아야되서          0.000286
# 3   복학한거처럼 보이는 형이 열심히는 하시던데 뭔가 군대갔다고오고 모든걸 까먹은 자기를...          0.000688
# 4                          9시 넘어야 갈수있을거 같은데\n열어 있을지..          0.000335
# 5   신입생 새터때 번호교환하고 학교서 인사만좀 하는사이였다가 연락 한 번도 안하고 군대...          0.009865
# 6             UHD 즉 4K면 코딩할때 글자 잘 안보이겠죠?\n그냥 FHD면 충분?          0.052737
# 7          정정기간때 신청해서 잘 모르겠어요. ㅠㅠ 계획서보니까 고른다고하는데 뭐에요
# 8           0.004254           0.008683           0.109738           0.013022
# 9           0.000465           0.000450           0.001739           0.000752
# 10          0.005907           0.001252           0.896450           0.004933
# 11          0.002116           0.001894           0.009816           0.002627
# 12          0.000260           0.000196           0.000642           0.000110
# 13          0.000262           0.000205           0.000681           0.000115
# 14          0.000277           0.000499           0.001546           0.004509
# 15          0.000247           0.000169           0.000535           0.000102
# 16          0.000235           0.000148           0.000522           0.000085
# 17          0.000253           0.000298           0.000295           0.000576
# 18          0.000215           0.000264           0.000249           0.000453
# 19          0.006483           0.006883           0.028811           0.006098
#
#     probs_category_13
# 0            0.002829
# 1            0.002713
# 2            0.000239
# 3            0.001996
# 4            0.000297
# 5            0.002961
# 6            0.018574
# 7            0.000801
# 8            0.003366
# 9            0.000121
# 10           0.000902
# 11           0.000469
# 12           0.000222
# 13           0.000228
# 14           0.002598
# 15           0.000238
# 16           0.000168
# 17           0.000596
# 18           0.000499
# 19           0.000966

# %%
# 예측 결과의 비율을 출력

threshold_counts = [0] * NUM_LABELS
total_count = len(df_results)

for i in range(NUM_LABELS):
    column_name = f'probs_category_{i}'
    threshold_counts[i] = (df_results[column_name] >= THRESHOLD).sum()

threshold_percentages = [(count / total_count * 100) for count in threshold_counts]

for i in range(NUM_LABELS):
    print(f'{CATEGORIES[i]} ({i}): {threshold_counts[i]} ({threshold_percentages[i]:.2f}%)')

plt.figure(figsize=(12, 8))
plt.bar(range(NUM_LABELS), threshold_counts)
for i, count in enumerate(threshold_counts):
    plt.text(i, count + 0.1, f'{count} ({threshold_percentages[i]:.2f}%)', ha='center')
plt.xlabel(f'Threshold ({THRESHOLD})')
plt.ylabel('Count')
plt.xticks(range(NUM_LABELS))
plt.title('Distribution of Predictions Above Threshold by Category')
plt.show()
# Out:
# 자유 (0): 47519 (15.88%)
# 학사 (1): 16456 (5.50%)
# 장학 · 행정 (2): 6859 (2.29%)
# 학교생활 (3): 12989 (4.34%)
# 수업 (4): 10209 (3.41%)
# 수업/이과 (5): 25745 (8.60%)
# 수업/문과 (6): 11780 (3.94%)
# 캠퍼스 (7): 17903 (5.98%)
# 취업 · 진로 (8): 17277 (5.77%)
# 일상생활 (9): 14293 (4.78%)
# 음식점 · 카페 (10): 4806 (1.61%)
# 취미 · 여가 (11): 13165 (4.40%)
# 인간관계 (12): 5254 (1.76%)
# 병역 (13): 4706 (1.57%)

# %%
# 예측 결과를 CSV 파일로 저장

df_results.to_csv(f'prediction_results.csv', index=False)

# %%
# 예측 결과를 DB에 저장

connection = db.get_connection()
cursor = connection.cursor()

sql_template = f'''
    INSERT INTO {TABLE_NAME} (id, {{columns}})
    VALUES (%s, {{placeholders}})
    ON DUPLICATE KEY UPDATE {{updates}}
'''

columns = ', '.join([f'probs_category_{i}' for i in range(NUM_LABELS)])
placeholders = ', '.join(['%s' for _ in range(NUM_LABELS)])
updates = ', '.join([f'probs_category_{i} = VALUES(probs_category_{i})' for i in range(NUM_LABELS)])

sql = sql_template.format(columns=columns, placeholders=placeholders, updates=updates)
values = [(row['id'],) + tuple(row[f'probs_category_{i}'] for i in range(NUM_LABELS)) for _, row in df_results.iterrows()]

cursor.executemany(sql, values)
connection.commit()

cursor.close()
db.close_connection()
