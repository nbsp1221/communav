# %%
# 다른 경로에 있는 모듈을 가져오기 위해 절대 경로 추가

import os
import sys

root = os.path.join(os.path.abspath(os.getcwd()), '..', '..')
root = os.path.normpath(root)

if root not in sys.path:
    sys.path.insert(0, root)

# %%
# 필요한 라이브러리 로드

import emoji
import json
import matplotlib.pyplot as plt
import os
import pandas as pd
import re
import torch
from communav.utils import db
from sklearn.metrics import accuracy_score, fbeta_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from soynlp.normalizer import repeat_normalize
from tqdm import tqdm
from transformers import AutoModelForSequenceClassification, AutoTokenizer, get_linear_schedule_with_warmup
# Out:
# /tmp/ipykernel_43233/1026082369.py:7: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# 카테고리 정의

CATEGORIES = {
    0: '자유',
    1: '학사',
    2: '장학 · 행정',
    3: '학교생활',
    4: '수업',
    5: '수업/이과',
    6: '수업/문과',
    7: '캠퍼스',
    8: '취업 · 진로',
    9: '일상생활',
    10: '음식점 · 카페',
    11: '취미 · 여가',
    12: '인간관계',
    13: '병역'
}

# %%
# 파라미터 설정

TABLE_NAME = 'everytime_article_dataset_v1'
MODEL_ID = 'model-iteration-15-epoch-28-0.9661'
TOKENIZER_ID = './custom-tokenizer'
NUM_LABELS = len(CATEGORIES)
MAX_LENGTH = 128
BATCH_SIZE = 32
THRESHOLD = 0.9
F_BETA = 0.5
METRIC_AVERAGE = 'weighted'
METRIC_ZERO_DIVISION = 0

# %%
# 커뮤니티 게시글 데이터 로드

connection = db.get_connection()
cursor = connection.cursor()

cursor.execute(f'''
    SELECT * FROM {TABLE_NAME}
''')
original_articles = cursor.fetchall()
print(f'Loaded {len(original_articles)} articles.')

cursor.close()
db.close_connection()
# Out:
# Connected to DB successfully.
# Loaded 299314 articles.

# %%
# 가져온 데이터의 일부를 출력

for article in original_articles[:20]:
    print(article)
# Out:
# {'id': 1, 'article_id': 21479637, 'title': '어제 비마관 화장실에서 핸드폰 찾아주신분!', 'text': '제가 경황이 없어서 감사하다고도 못 했네요.\n정말 감사합니다!!!', 'category_id': 9, 'is_verified': 1, 'possible_category_id': 9, 'probs_category_0': 2.423e-05, 'probs_category_1': 7.25855e-06, 'probs_category_2': 2.43262e-05, 'probs_category_3': 2.95715e-05, 'probs_category_4': 5.24089e-06, 'probs_category_5': 3.9223e-05, 'probs_category_6': 2.24422e-05, 'probs_category_7': 7.76284e-05, 'probs_category_8': 3.81866e-05, 'probs_category_9': 0.99925, 'probs_category_10': 9.00379e-05, 'probs_category_11': 0.000286288, 'probs_category_12': 9.32753e-05, 'probs_category_13': 1.21927e-05}
# {'id': 2, 'article_id': 21480514, 'title': '클럽좋아하시는분 계세요~?', 'text': '남자 신입생인데 주말에갈려하는데 같이가실분 괌', 'category_id': None, 'is_verified': None, 'possible_category_id': 11, 'probs_category_0': 0.00017646, 'probs_category_1': 7.29264e-05, 'probs_category_2': 1.5635e-05, 'probs_category_3': 0.000577914, 'probs_category_4': 6.57191e-05, 'probs_category_5': 0.000101221, 'probs_category_6': 0.000274094, 'probs_category_7': 7.84048e-05, 'probs_category_8': 0.000254924, 'probs_category_9': 0.000934388, 'probs_category_10': 9.49978e-05, 'probs_category_11': 0.985951, 'probs_category_12': 0.0112515, 'probs_category_13': 0.000150344}
# {'id': 3, 'article_id': 21480639, 'title': '조은문화사 몇시에 보통 열리나요??', 'text': '1교시 수업 책 찾아야되서', 'category_id': 7, 'is_verified': 1, 'possible_category_id': 7, 'probs_category_0': 1.17931e-05, 'probs_category_1': 4.64807e-05, 'probs_category_2': 1.79555e-05, 'probs_category_3': 6.53837e-05, 'probs_category_4': 7.32421e-06, 'probs_category_5': 3.75018e-06, 'probs_category_6': 1.65023e-05, 'probs_category_7': 0.999535, 'probs_category_8': 2.17895e-05, 'probs_category_9': 0.000103044, 'probs_category_10': 0.00012122, 'probs_category_11': 1.93621e-05, 'probs_category_12': 9.96612e-06, 'probs_category_13': 2.07971e-05}
# {'id': 4, 'article_id': 21481049, 'title': '전공수업듣는데', 'text': '복학한거처럼 보이는 형이 열심히는 하시던데 뭔가 군대갔다고오고 모든걸 까먹은 자기를 자책하듯이 수업듣는걸 보고 나도 3년후에 저러겠구나 싶더라... ㅠㅠ', 'category_id': 4, 'is_verified': None, 'possible_category_id': 4, 'probs_category_0': 3.13525e-05, 'probs_category_1': 0.000123441, 'probs_category_2': 4.35226e-05, 'probs_category_3': 0.000127983, 'probs_category_4': 0.998117, 'probs_category_5': 0.00110624, 'probs_category_6': 0.000220263, 'probs_category_7': 2.32596e-05, 'probs_category_8': 0.000122173, 'probs_category_9': 1.68459e-05, 'probs_category_10': 6.18198e-06, 'probs_category_11': 1.50097e-05, 'probs_category_12': 2.73582e-05, 'probs_category_13': 1.98142e-05}
# {'id': 5, 'article_id': 21481575, 'title': '정문에 있는 인쇄집들 몇시까지 하는지 아시나요?', 'text': '9시 넘어야 갈수있을거 같은데\n열어 있을지..', 'category_id': 7, 'is_verified': 1, 'possible_category_id': 7, 'probs_category_0': 1.39165e-05, 'probs_category_1': 4.69223e-05, 'probs_category_2': 2.56588e-05, 'probs_category_3': 5.34483e-05, 'probs_category_4': 8.91763e-06, 'probs_category_5': 4.18788e-06, 'probs_category_6': 1.91106e-05, 'probs_category_7': 0.999565, 'probs_category_8': 2.70551e-05, 'probs_category_9': 9.69276e-05, 'probs_category_10': 9.06205e-05, 'probs_category_11': 1.89029e-05, 'probs_category_12': 1.0521e-05, 'probs_category_13': 1.88743e-05}
# {'id': 6, 'article_id': 21482091, 'title': '이런사람들 많나?', 'text': '신입생 새터때 번호교환하고 학교서 인사만좀 하는사이였다가 연락 한 번도 안하고 군대가고 카톡친추는 되어있어서 누군지는 알고 복학하고 오니 서로 얼굴은아는데 인사하기도 민망하고 껄끄러운사이 너무 불편하다 엮일일 없으면 상관없는데 자꾸 마주치면 괜히 불편함', 'category_id': None, 'is_verified': None, 'possible_category_id': 3, 'probs_category_0': 0.00259824, 'probs_category_1': 0.000270333, 'probs_category_2': 5.02974e-05, 'probs_category_3': 0.517232, 'probs_category_4': 0.000853224, 'probs_category_5': 0.000193565, 'probs_category_6': 0.000554428, 'probs_category_7': 0.000808542, 'probs_category_8': 0.000992923, 'probs_category_9': 0.00107024, 'probs_category_10': 5.78501e-05, 'probs_category_11': 0.00211571, 'probs_category_12': 0.472717, 'probs_category_13': 0.000485582}
# {'id': 7, 'article_id': 21482097, 'title': '해상도!', 'text': 'UHD 즉 4K면 코딩할때 글자 잘 안보이겠�
자회로실험 파형이 물결처럼 나와야하는데 왜 난 일자로 나오지???;;', 'text': '이번에 복학해서 실험들으려는데 그냥 예비는 똑같이 따라하면 되는거 아닌가?\n왜 일자로만 나와....', 'category_id': 5, 'is_verified': None, 'possible_category_id': 5, 'probs_category_0': 7.05697e-06, 'probs_category_1': 4.62988e-05, 'probs_category_2': 1.45252e-05, 'probs_category_3': 1.54566e-05, 'probs_category_4': 5.52581e-05, 'probs_category_5': 0.999587, 'probs_category_6': 9.88201e-05, 'probs_category_7': 6.3906e-06, 'probs_category_8': 4.44001e-05, 'probs_category_9': 6.20944e-05, 'probs_category_10': 3.54326e-05, 'probs_category_11': 1.01864e-05, 'probs_category_12': 7.29607e-06, 'probs_category_13': 1.02935e-05}
# {'id': 14, 'article_id': 21484291, 'title': '전자회로실험 파형이 물결처럼 나와야하는데 왜 난 일자로 나오지???;;', 'text': '이번에 복학해서 실험들으려는데 그냥 예비는 똑같이 따라하면 되는거 아닌가?\n왜 일자로만 나와....\n이건 회로인데 뭐가 잘못된거지요????;;', 'category_id': 5, 'is_verified': None, 'possible_category_id': 5, 'probs_category_0': 7.314e-06, 'probs_category_1': 4.61523e-05, 'probs_category_2': 1.4832e-05, 'probs_category_3': 1.59083e-05, 'probs_category_4': 5.34274e-05, 'probs_category_5': 0.999585, 'probs_category_6': 9.67133e-05, 'probs_category_7': 6.4266e-06, 'probs_category_8': 4.56555e-05, 'probs_category_9': 6.38026e-05, 'probs_category_10': 3.64085e-05, 'probs_category_11': 1.03613e-05, 'probs_category_12': 7.36567e-06, 'probs_category_13': 1.04186e-05}
# {'id': 15, 'article_id': 21484434, 'title': '이쯤에서 질문', 'text': '전공서적 (2 3 4학년 상관없음)\n1. 새책산다\n2. 중고로 산다\n3. 제본뜬다\n4. 물려받는다\n새책사거나 중고사신분 또 질문\na. 중고로 판다\nb. 그냥 가지고 있는다\nc. 물려준다', 'category_id': None, 'is_verified': None, 'possible_category_id': 4, 'probs_category_0': 0.046535, 'probs_category_1': 0.00364684, 'probs_category_2': 0.00043516, 'probs_category_3': 0.0124001, 'probs_category_4': 0.716776, 'probs_category_5': 0.00572642, 'probs_category_6': 0.0187561, 'probs_category_7': 0.00062782, 'probs_category_8': 0.0688409, 'probs_category_9': 0.00152558, 'probs_category_10': 0.000407897, 'probs_category_11': 0.103156, 'probs_category_12': 0.020451, 'probs_category_13': 0.000715354}
# {'id': 16, 'article_id': 21484856, 'title': '화공과 유기화학1수업 책 : 스미스 유기화학', 'text': '번역판 샀는데 원서없으면 시험보기힘든가요?', 'category_id': None, 'is_verified': None, 'possible_category_id': 5, 'probs_category_0': 6.62795e-06, 'probs_category_1': 3.68729e-05, 'probs_category_2': 1.28987e-05, 'probs_category_3': 1.34964e-05, 'probs_category_4': 5.96199e-05, 'probs_category_5': 0.999606, 'probs_category_6': 0.000104706, 'probs_category_7': 5.66105e-06, 'probs_category_8': 4.19602e-05, 'probs_category_9': 5.52944e-05, 'probs_category_10': 2.97547e-05, 'probs_category_11': 9.71368e-06, 'probs_category_12': 6.90414e-06, 'probs_category_13': 1.03595e-05}
# {'id': 17, 'article_id': 21485394, 'title': '컴퓨터구조 책삽니다', 'text': '표지에 컴퓨터구조 및 설계 써있고 5판 한글판 중고 2만원에삽니다\nPatterson , Hennessy 저자 입니다', 'category_id': 5, 'is_verified': None, 'possible_category_id': 5, 'probs_category_0': 6.70894e-06, 'probs_category_1': 4.10894e-05, 'probs_category_2': 1.43109e-05, 'probs_category_3': 1.32644e-05, 'probs_category_4': 5.41983e-05, 'probs_category_5': 0.999605, 'probs_category_6': 9.21998e-05, 'probs_category_7': 5.95476e-06, 'probs_category_8': 4.52704e-05, 'probs_category_9': 6.3563e-05, 'probs_category_10': 3.08574e-05, 'probs_category_11': 9.46055e-06, 'probs_category_12': 7.23374e-06, 'probs_category_13': 1.0398e-05}
# {'id': 18, 'article_id': 21485924, 'title': '오늘 영화의 이해 수업', 'text': '영화의 이해 유양근 교수님 수업을 못가서 그런데 혹시 교재같은거나 해오라고 하신거 있나요?! ㅜㅜ', 'category_id': 6, 'is_verified': None, 'possible_category_id': 6, 'probs_category_0': 3.07432e-05, 'probs_category_1': 3.48698e-05, 'probs_category_2': 1.67465e-05, 'probs_category_3': 3.86784e-05, 'probs_category_4': 0.000228125, 'probs_category_5': 0.000376538, 'probs_category_6': 0.999088, 'probs_category_7': 2.67546e-05, 'probs_category_8': 3.51786e-05, 'probs_category_9': 1.35289e-05, 'probs_category_10': 9.67746e-06, 'probs_category_11': 7.87895e-05, 'probs_category_12': 1.54711e-05, 'probs_category_13': 6.88186e-06}
# {'id': 19, 'article_id': 21485950, 'title': '초급일본어', 'text': '전유나 초급일본어 책필요한가요?', 'category_id': 6, 'is_verified': None, 'possible_category_id': 6, 'probs_category_0': 1.91432e-05, 'probs_category_1': 2.76918e-05, 'probs_category_2': 1.4253e-05, 'probs_category_3': 3.45211e-05, 'probs_category_4': 0.000104968, 'probs_category_5': 0.000305845, 'probs_category_6': 0.999331, 'probs_category_7': 2.26157e-05, 'probs_category_8': 2.29069e-05, 'probs_category_9': 1.42193e-05, 'probs_category_10': 1.18108e-05, 'probs_category_11': 7.39656e-05, 'probs_category_12': 1.17372e-05, 'probs_category_13': 5.40588e-06}
# {'id': 20, 'article_id': 21487104, 'title': '나 진짜 어릴 때부터 궁금하던 건데 알려줄 사람', 'text': '버스 안에서 제자리 비행하고 있는 파리는\n버스가 앞으로 움직이면 버스 뒷자석에 부딪혀야 하자나...\n근데 왜 안 부딪혀', 'category_id': None, 'is_verified': None, 'possible_category_id': 0, 'probs_category_0': 0.943194, 'probs_category_1': 0.000158379, 'probs_category_2': 0.000113912, 'probs_category_3': 0.00960823, 'probs_category_4': 0.000601311, 'probs_category_5': 0.000168497, 'probs_category_6': 0.000442758, 'probs_category_7': 0.00037841, 'probs_category_8': 0.00278253, 'probs_category_9': 0.00289513, 'probs_category_10': 0.000820428, 'probs_category_11': 0.0305507, 'probs_category_12': 0.00792283, 'probs_category_13': 0.000362737}

# %%
# 데이터 전처리 함수 정의

normal_pattern = re.compile(r'[^ .,?!/@$%~％·∼()\x00-\x7Fㄱ-ㅣ가-힣]+')
url_pattern = re.compile(r'https?:\/\/(www\.)?[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)')

def preprocess(value):
    value = normal_pattern.sub(' ', value)
    value = emoji.replace_emoji(value, replace='')
    value = url_pattern.sub('', value)
    value = repeat_normalize(value, num_repeats=2)
    value = value.strip()
    return value

# %%
# 데이터 전처리

contents = [preprocess(article['title'] + ' ' + article['text']) for article in tqdm(original_articles)]
# Out:
# 100%|██████████| 299314/299314 [00:10<00:00, 29308.27it/s]

# %%
# 전처리된 데이터의 일부를 출력

for content in contents[:20]:
    print(content)
# Out:
# 어제 비마관 화장실에서 핸드폰 찾아주신분! 제가 경황이 없어서 감사하다고도 못 했네요. 정말 감사합니다!!!
# 클럽좋아하시는분 계세요~? 남자 신입생인데 주말에갈려하는데 같이가실분 괌
# 조은문화사 몇시에 보통 열리나요?? 1교시 수업 책 찾아야되서
# 전공수업듣는데 복학한거처럼 보이는 형이 열심히는 하시던데 뭔가 군대갔다고오고 모든걸 까먹은 자기를 자책하듯이 수업듣는걸 보고 나도 3년후에 저러겠구나 싶더라... ㅠㅠ
# 정문에 있는 인쇄집들 몇시까지 하는지 아시나요? 9시 넘어야 갈수있을거 같은데 열어 있을지..
# 이런사람들 많나? 신입생 새터때 번호교환하고 학교서 인사만좀 하는사이였다가 연락 한 번도 안하고 군대가고 카톡친추는 되어있어서 누군지는 알고 복학하고 오니 서로 얼굴은아는데 인사하기도 민망하고 껄끄러운사이 너무 불편하다 엮일일 없으면 상관없는데 자꾸 마주치면 괜히 불편함
# 해상도! UHD 즉 4K면 코딩할때 글자 잘 안보이겠죠? 그냥 FHD면 충분?
# 문화유목시대 교재뭔가요 정정기간때 신청해서 잘 모르겠어요. ㅠㅠ 계획서보니까 고른다고하는데 뭐에요?
# 난 멋있어 멋있어
# 내일 공강이다 불기둥 같은 월화수를 마치고 목금이 오긴 왔네...
# 힙동 들어가고싶긴한데 커버밖에 못하고 리얼 힙찔이라 엄두가안난다
# 바람지원했는데요 아직 연락이 안왔는데 다들 안온건가요!?
# 전자회로실험 파형이 물결처럼 나와야하는데 왜 난 일자로 나오지???;; 이번에 복학해서 실험들으려는데 그냥 예비는 똑같이 따라하면 되는거 아닌가? 왜 일자로만 나와....
# 전자회로실험 파형이 물결처럼 나와야하는데 왜 난 일자로 나오지???;; 이번에 복학해서 실험들으려는데 그냥 예비는 똑같이 따라하면 되는거 아닌가? 왜 일자로만 나와.... 이건 회로인데 뭐가 잘못된거지요????;;
# 이쯤에서 질문 전공서적 (2 3 4학년 상관없음) 1. 새책산다 2. 중고로 산다 3. 제본뜬다 4. 물려받는다 새책사거나 중고사신분 또 질문 a. 중고로 판다 b. 그냥 가지고 있는다 c. 물려준다
# 화공과 유기화학1수업 책 : 스미스 유기화학 번역판 샀는데 원서없으면 시험보기힘든가요?
# 컴퓨터구조 책삽니다 표지에 컴퓨터구조 및 설계 써있고 5판 한글판 중고 2만원에삽니다 Patterson , Hennessy 저자 입니다
# 오늘 영화의 이해 수업 영화의 이해 유양근 교수님 수업을 못가서 그런데 혹시 교재같은거나 해오라고 하신거 있나요?! ㅜㅜ
# 초급일본어 전유나 초급일본어 책필요한가요?
# 나 진짜 어릴 때부터 궁금하던 건데 알려줄 사람 버스 안에서 제자리 비행하고 있는 파리는 버스가 앞으로 움직이면 버스 뒷자석에 부딪혀야 하자나... 근데 왜 안 부딪혀

# %%
# 토크나이저 로드

tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_ID)

print('Original:', contents[0])
print('Tokenized:', tokenizer.tokenize(contents[0]))
# Out:
# Original: 어제 비마관 화장실에서 핸드폰 찾아주신분! 제가 경황이 없어서 감사하다고도 못 했네요. 정말 감사합니다!!!
# Tokenized: ['어제', '비', '##마', '##관', '화장실', '##에서', '핸드폰', '찾아', '##주신', '##분', '!', '제가', '경', '##황', '##이', '없어서', '감사', '##하다고', '##도', '못', '했네요', '.', '정말', '감사합니다', '!', '!', '!']

# %%
# 모델 로드

if torch.cuda.is_available():
    device = torch.device('cuda')
    print('There are %d GPU(s) available.' % torch.cuda.device_count())
    print('We will use the GPU:', torch.cuda.get_device_name(0))
else:
    device = torch.device('cpu')
    print('No GPU available, using the CPU instead.')

model = AutoModelForSequenceClassification.from_pretrained(MODEL_ID, num_labels=NUM_LABELS)
model.to(device)
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 3060 Ti
# ElectraForSequenceClassification(
#   (electra): ElectraModel(
#     (embeddings): ElectraEmbeddings(
#       (word_embeddings): Embedding(54397, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): ElectraEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): ElectraClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): GELUActivation()
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=14, bias=True)
#   )
# )

# %%
# 모델 세부 정보 수정

model.resize_token_embeddings(len(tokenizer))
# Out:
# Embedding(54397, 768, padding_idx=0)

# %%
# 텍스트 인코딩 및 데이터셋 생성

encodings = tokenizer(
    contents,
    padding=True,
    truncation=True,
    return_tensors='pt',
    max_length=MAX_LENGTH
)
dataset = torch.utils.data.TensorDataset(
    torch.tensor(encodings['input_ids']),
    torch.tensor(encodings['attention_mask'])
)
dataloader = torch.utils.data.DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# /tmp/ipykernel_43233/3188963195.py:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(encodings['input_ids']),
# /tmp/ipykernel_43233/3188963195.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(encodings['attention_mask'])

# %%
# 예측 수행

columns = [
    'id',
    'title',
    'text',
    'category_id',
    'possible_category_id',
    'predicted_category_id',
    *[f'probs_category_{i}' for i in range(NUM_LABELS)]
]
df_results = pd.DataFrame(original_articles, columns=columns)
df_results['category_id'] = df_results['category_id'].fillna(-1).astype(int)

for i, batch in enumerate(tqdm(dataloader, desc='Predicting')):
    input_ids = batch[0].to(device)
    attention_mask = batch[1].to(device)

    with torch.no_grad():
        outputs = model(input_ids, attention_mask=attention_mask)
        logits = outputs.logits
        predictions = torch.argmax(logits, dim=1)
        probabilities = torch.softmax(logits, dim=1)

    start_index = i * BATCH_SIZE
    end_index = start_index + BATCH_SIZE

    df_results.loc[start_index:end_index - 1, 'predicted_category_id'] = predictions.tolist()
    for j in range(NUM_LABELS):
        df_results.loc[start_index:end_index - 1, f'probs_category_{j}'] = probabilities[:, j].tolist()

df_results['predicted_category_id'] = df_results['predicted_category_id'].astype(int)

print('Prediction completed.')
# Out:
# Predicting: 100%|██████████| 9354/9354 [18:32<00:00,  8.40it/s]
# Prediction completed.

# %%
# 예측 결과의 일부를 출력

df_results.head(20)
# Out:
#     id                                    title  \
# 0    1                  어제 비마관 화장실에서 핸드폰 찾아주신분!
# 1    2                           클럽좋아하시는분 계세요~?
# 2    3                      조은문화사 몇시에 보통 열리나요??
# 3    4                                  전공수업듣는데
# 4    5               정문에 있는 인쇄집들 몇시까지 하는지 아시나요?
# 5    6                                이런사람들 많나?
# 6    7                                     해상도!
# 7    8                             문화유목시대 교재뭔가요
# 8    9                                        난
# 9   10                                  내일 공강이다
# 10  11                              힙동 들어가고싶긴한데
# 11  12                                 바람지원했는데요
# 12  13  전자회로실험 파형이 물결처럼 나와야하는데 왜 난 일자로 나오지???;;
# 13  14  전자회로실험 파형이 물결처럼 나와야하는데 왜 난 일자로 나오지???;;
# 14  15                                  이쯤에서 질문
# 15  16                 화공과 유기화학1수업 책 : 스미스 유기화학
# 16  17                               컴퓨터구조 책삽니다
# 17  18                             오늘 영화의 이해 수업
# 18  19                                    초급일본어
# 19  20               나 진짜 어릴 때부터 궁금하던 건데 알려줄 사람
#
#                                                  text  category_id  \
# 0               제가 경황이 없어서 감사하다고도 못 했네요.\n정말 감사합니다!!!            9
# 1                           남자 신입생인데 주말에갈려하는데 같이가실분 괌           -1
# 2                                      1교시 수업 책 찾아야되서            7
# 3   복학한거처럼 보이는 형이 열심히는 하시던데 뭔가 군대갔다고오고 모든걸 까먹은 자기를...            4
# 4                          9시 넘어야 갈수있을거 같은데\n열어 있을지..            7
# 5   신입생 새터때 번호교환하고 학교서 인사만좀 하는사이였다가 연락 한 번도 안하고 군대...           -1
# 6             UHD 즉 4K면 코딩할때 글자 잘 안보이겠죠?\n그냥 FHD면 충분?           -1
# 7          정정기간때 신청해서 잘 모르겠어요. ㅠㅠ 계획서보니까 고른다고하는데 뭐에요?            6
# 8                                             멋있어 멋있어           -1
# 9                        불기둥 같은 월화수를 마치고 목금이 오긴 왔네...           -1
# 10                           커버밖에 못하고\n리얼 힙찔이라 엄두가안난다           -1
# 11                             아직 연락이 안왔는데 다들 안온건가요!?           -1
# 12  이번에 복학해서 실험들으려는데 그냥 예비는 똑같이 따라하면 되는거 아닌가?\n왜 
# 2           0.000052           0.000230           0.000017           0.000008
# 3           0.000017           0.000045           0.000026           0.000053
# 4           0.000072           0.000247           0.000016           0.000007
# 5           0.397081           0.023031           0.009653           0.008579
# 6           0.999015           0.000235           0.000178           0.000077
# 7           0.000013           0.000082           0.000016           0.000048
# 8           0.000981           0.000580           0.838927           0.002342
# 9           0.000020           0.000183           0.000959           0.000133
# 10          0.000115           0.000364           0.998249           0.000222
# 11          0.425912           0.002453           0.458719           0.003942
# 12          0.000024           0.000018           0.000002           0.000004
# 13          0.000025           0.000017           0.000002           0.000004
# 14          0.000080           0.000111           0.000040           0.000102
# 15          0.000023           0.000020           0.000002           0.000004
# 16          0.000074           0.000030           0.000006           0.000007
# 17          0.000010           0.000042           0.000011           0.000038
# 18          0.000016           0.000117           0.000023           0.000043
# 19          0.000176           0.000020           0.000605           0.000084
#
#     probs_category_13
# 0            0.000028
# 1            0.000163
# 2            0.000085
# 3            0.000030
# 4            0.000075
# 5            0.000553
# 6            0.000022
# 7            0.000009
# 8            0.001668
# 9            0.000008
# 10           0.000176
# 11           0.001630
# 12           0.000010
# 13           0.000010
# 14           0.000022
# 15           0.000007
# 16           0.000013
# 17           0.000011
# 18           0.000011
# 19           0.000092

# %%
# 평가 지표 계산 함수 정의

def calculate_metrics(true_labels, predicted_labels):
    acc = accuracy_score(true_labels, predicted_labels)
    prec = precision_score(true_labels, predicted_labels, average=METRIC_AVERAGE, zero_division=METRIC_ZERO_DIVISION)
    rec = recall_score(true_labels, predicted_labels, average=METRIC_AVERAGE, zero_division=METRIC_ZERO_DIVISION)
    f_beta = fbeta_score(true_labels, predicted_labels, beta=F_BETA, average=METRIC_AVERAGE, zero_division=METRIC_ZERO_DIVISION)

    return acc, prec, rec, f_beta

# %%
# 평가 지표 출력

labels = []
predictions = []

for i in range(len(df_results)):
    if df_results.loc[i, 'category_id'] != -1:
        labels.append(df_results.loc[i, 'category_id'])
        predictions.append(df_results.loc[i, 'predicted_category_id'])

acc, prec, rec, f_beta = calculate_metrics(labels, predictions)

print(f'Accuracy: {acc:.4f}')
print(f'Precision: {prec:.4f}')
print(f'Recall: {rec:.4f}')
print(f'F-Beta Score: {f_beta:.4f}')
# Out:
# Accuracy: 0.9932
# Precision: 0.9932
# Recall: 0.9932
# F-Beta Score: 0.9932

# %%
# 예측 결과의 비율을 출력

threshold_counts = [0] * NUM_LABELS
total_count = len(df_results)

for i in range(NUM_LABELS):
    column_name = f'probs_category_{i}'
    threshold_counts[i] = (df_results[column_name] >= THRESHOLD).sum()

threshold_percentages = [(count / total_count * 100) for count in threshold_counts]

for i in range(NUM_LABELS):
    print(f'{CATEGORIES[i]} ({i}): {threshold_counts[i]} ({threshold_percentages[i]:.2f}%)')

plt.figure(figsize=(12, 8))
plt.bar(range(NUM_LABELS), threshold_counts)
for i, count in enumerate(threshold_counts):
    plt.text(i, count + 0.1, f'{count} ({threshold_percentages[i]:.2f}%)', ha='center')
plt.xlabel(f'Threshold ({THRESHOLD})')
plt.ylabel('Count')
plt.xticks(range(NUM_LABELS))
plt.title('Distribution of Predictions Above Threshold by Category')
plt.show()
# Out:
# 자유 (0): 38455 (12.85%)
# 학사 (1): 15556 (5.20%)
# 장학 · 행정 (2): 8716 (2.91%)
# 학교생활 (3): 8581 (2.87%)
# 수업 (4): 23522 (7.86%)
# 수업/이과 (5): 28817 (9.63%)
# 수업/문과 (6): 24007 (8.02%)
# 캠퍼스 (7): 20647 (6.90%)
# 취업 · 진로 (8): 14559 (4.86%)
# 일상생활 (9): 28634 (9.57%)
# 음식점 · 카페 (10): 7072 (2.36%)
# 취미 · 여가 (11): 18720 (6.25%)
# 인간관계 (12): 4917 (1.64%)
# 병역 (13): 5553 (1.86%)

# %%
# 기존 카테고리와 예측 카테고리가 다른 경우의 비율을 출력

changed_counts = [0] * NUM_LABELS
total_count = len(df_results)

for i in range(total_count):
    possible_category_id = df_results.loc[i, 'possible_category_id']
    predicted_category_id = df_results.loc[i, 'predicted_category_id']
    if possible_category_id != predicted_category_id:
        changed_counts[possible_category_id] += 1

changed_percentages = [(count / total_count * 100) for count in changed_counts]
total_changed_count = sum(changed_counts)
total_changed_percentage = total_changed_count / total_count * 100

print(f'Total changed count: {total_changed_count} ({total_changed_percentage:.2f}%)')
for i in range(NUM_LABELS):
    print(f'{CATEGORIES[i]} [{i}]: {changed_counts[i]} ({changed_percentages[i]:.2f}%)')

plt.figure(figsize=(12, 8))
plt.bar(range(NUM_LABELS), changed_counts)
for i, count in enumerate(changed_counts):
    plt.text(i, count + 0.1, f'{count} ({changed_percentages[i]:.2f}%)', ha='center')
plt.xlabel('Category')
plt.ylabel('Changed Count')
plt.xticks(range(NUM_LABELS))
plt.title('Distribution of Changed Predictions by Category')
plt.tight_layout()
plt.show()
# Out:
# Total changed count: 91875 (30.70%)
# 자유 [0]: 6384 (2.13%)
# 학사 [1]: 5233 (1.75%)
# 장학 · 행정 [2]: 2023 (0.68%)
# 학교생활 [3]: 15562 (5.20%)
# 수업 [4]: 5595 (1.87%)
# 수업/이과 [5]: 13300 (4.44%)
# 수업/문과 [6]: 5763 (1.93%)
# 캠퍼스 [7]: 3545 (1.18%)
# 취업 · 진로 [8]: 7377 (2.46%)
# 일상생활 [9]: 4684 (1.56%)
# 음식점 · 카페 [10]: 1592 (0.53%)
# 취미 · 여가 [11]: 14951 (5.00%)
# 인간관계 [12]: 3767 (1.26%)
# 병역 [13]: 2099 (0.70%)

# %%
# 예측 결과를 CSV 파일로 저장

df_results.to_csv(f'prediction-results.csv', index=False)

# %%
# 예측 결과를 DB에 저장

connection = db.get_connection()
cursor = connection.cursor()

sql_template = f'''
    INSERT INTO {TABLE_NAME} (id, possible_category_id, {{columns}})
    VALUES (%s, %s, {{placeholders}})
    ON DUPLICATE KEY UPDATE
        possible_category_id = VALUES(possible_category_id),
        {{updates}}
'''

columns = ', '.join([f'probs_category_{i}' for i in range(NUM_LABELS)])
placeholders = ', '.join(['%s' for _ in range(NUM_LABELS)])
updates = ', '.join([f'probs_category_{i} = VALUES(probs_category_{i})' for i in range(NUM_LABELS)])

sql = sql_template.format(columns=columns, placeholders=placeholders, updates=updates)
values = [(row['id'], row['predicted_category_id'],) + tuple(row[f'probs_category_{i}'] for i in range(NUM_LABELS)) for _, row in df_results.iterrows()]

cursor.executemany(sql, values)
connection.commit()

cursor.close()
db.close_connection()
# Out:
# Connected to DB successfully.
