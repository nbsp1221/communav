# %%
# 다른 경로에 있는 모듈을 가져오기 위해 절대 경로 추가

import os
import sys

root = os.path.join(os.path.abspath(os.getcwd()), '..', '..')
root = os.path.normpath(root)

if root not in sys.path:
    sys.path.insert(0, root)

# %%
# 필요한 라이브러리 로드

import emoji
import json
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import random
import re
import torch
from communav.utils import db
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from soynlp.normalizer import repeat_normalize
from tqdm import tqdm
from transformers import AutoModelForSequenceClassification, AutoTokenizer, get_linear_schedule_with_warmup
# Out:
# /tmp/ipykernel_137163/2000937440.py:8: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# 카테고리 정의

CATEGORIES = {
    0: '자유',
    1: '학사',
    2: '장학 · 행정',
    3: '학교생활',
    4: '수업',
    5: '수업/이과',
    6: '수업/문과',
    7: '캠퍼스',
    8: '취업 · 진로',
    9: '일상생활',
    10: '음식점 · 카페',
    11: '취미 · 여가',
    12: '인간관계',
    13: '병역'
}

# %%
# 파라미터 설정

TABLE_NAME = 'everytime_article_dataset_v1'
MODEL_ID = '.model-iteration-64-epoch-12-0.9582'
TOKENIZER_ID = '.model-iteration-64-epoch-12-0.9582'
SEED = 42
USE_RANDOM_SEED = True
NUM_LABELS = len(CATEGORIES)
MAX_LENGTH = 128
METRIC_AVERAGE = 'weighted'
METRIC_ZERO_DIVISION = 0
BATCH_SIZE = 32
THRESHOLD = 0.5

# %%
# 랜덤 시드 고정

if torch.cuda.is_available():
    device = torch.device('cuda')
    print('There are %d GPU(s) available.' % torch.cuda.device_count())
    print('We will use the GPU:', torch.cuda.get_device_name(0))
else:
    device = torch.device('cpu')
    print('No GPU available, using the CPU instead.')

if not USE_RANDOM_SEED:
    random.seed(SEED)
    np.random.seed(SEED)
    torch.manual_seed(SEED)
    if device.type == 'cuda':
        torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 3060 Ti

# %%
# 커뮤니티 게시글 데이터 로드

connection = db.get_connection()
cursor = connection.cursor()

cursor.execute(f'''
    SELECT * FROM {TABLE_NAME}
''')
original_articles = cursor.fetchall()
print(f'Loaded {len(original_articles)} articles.')

cursor.close()
db.close_connection()
# Out:
# Connected to DB successfully.
# Loaded 299314 articles.

# %%
# 가져온 데이터의 일부를 출력

for article in original_articles[:20]:
    print(article)
# Out:
# {'id': 1, 'article_id': 21479637, 'title': '어제 비마관 화장실에서 핸드폰 찾아주신분!', 'text': '제가 경황이 없어서 감사하다고도 못 했네요.\n정말 감사합니다!!!', 'category_id': 9, 'is_verified': 1, 'possible_category_id': 9, 'probs_category_0': 0.0028829, 'probs_category_1': 0.00020712, 'probs_category_2': 0.000260727, 'probs_category_3': 6.46357e-05, 'probs_category_4': 4.84098e-05, 'probs_category_5': 9.69759e-06, 'probs_category_6': 4.07982e-05, 'probs_category_7': 0.000438644, 'probs_category_8': 8.59291e-05, 'probs_category_9': 0.994373, 'probs_category_10': 0.000606838, 'probs_category_11': 0.000401992, 'probs_category_12': 0.000305779, 'probs_category_13': 0.000273992}
# {'id': 2, 'article_id': 21480514, 'title': '클럽좋아하시는분 계세요~?', 'text': '남자 신입생인데 주말에갈려하는데 같이가실분 괌', 'category_id': None, 'is_verified': None, 'possible_category_id': 11, 'probs_category_0': 0.000897024, 'probs_category_1': 0.000141423, 'probs_category_2': 1.96468e-05, 'probs_category_3': 0.000895898, 'probs_category_4': 0.00010174, 'probs_category_5': 0.000106053, 'probs_category_6': 0.000238012, 'probs_category_7': 0.000188287, 'probs_category_8': 0.000436337, 'probs_category_9': 0.00256078, 'probs_category_10': 0.000733513, 'probs_category_11': 0.981399, 'probs_category_12': 0.011821, 'probs_category_13': 0.00046178}
# {'id': 3, 'article_id': 21480639, 'title': '조은문화사 몇시에 보통 열리나요??', 'text': '1교시 수업 책 찾아야되서', 'category_id': 7, 'is_verified': 1, 'possible_category_id': 7, 'probs_category_0': 1.61465e-05, 'probs_category_1': 8.11756e-05, 'probs_category_2': 0.000247088, 'probs_category_3': 0.000532935, 'probs_category_4': 0.00013138, 'probs_category_5': 0.000216296, 'probs_category_6': 4.26933e-05, 'probs_category_7': 0.997201, 'probs_category_8': 2.51905e-05, 'probs_category_9': 0.000251897, 'probs_category_10': 0.000985324, 'probs_category_11': 7.8236e-05, 'probs_category_12': 1.77543e-05, 'probs_category_13': 0.00017258}
# {'id': 4, 'article_id': 21481049, 'title': '전공수업듣는데', 'text': '복학한거처럼 보이는 형이 열심히는 하시던데 뭔가 군대갔다고오고 모든걸 까먹은 자기를 자책하듯이 수업듣는걸 보고 나도 3년후에 저러겠구나 싶더라... ㅠㅠ', 'category_id': 4, 'is_verified': None, 'possible_category_id': 4, 'probs_category_0': 0.000523149, 'probs_category_1': 0.000760287, 'probs_category_2': 0.000121058, 'probs_category_3': 0.000321596, 'probs_category_4': 0.995925, 'probs_category_5': 0.00038683, 'probs_category_6': 0.000199185, 'probs_category_7': 0.000302104, 'probs_category_8': 0.000671832, 'probs_category_9': 0.00010268, 'probs_category_10': 0.000199818, 'probs_category_11': 0.000111931, 'probs_category_12': 0.000141952, 'probs_category_13': 0.000232455}
# {'id': 5, 'article_id': 21481575, 'title': '정문에 있는 인쇄집들 몇시까지 하는지 아시나요?', 'text': '9시 넘어야 갈수있을거 같은데\n열어 있을지..', 'category_id': 7, 'is_verified': 1, 'possible_category_id': 7, 'probs_category_0': 1.89223e-05, 'probs_category_1': 9.66837e-05, 'probs_category_2': 0.000265066, 'probs_category_3': 0.000298439, 'probs_category_4': 0.000118024, 'probs_category_5': 0.000243366, 'probs_category_6': 4.61561e-05, 'probs_category_7': 0.996965, 'probs_category_8': 2.44183e-05, 'probs_category_9': 0.000349633, 'probs_category_10': 0.00128747, 'probs_category_11': 7.97307e-05, 'probs_category_12': 1.92234e-05, 'probs_category_13': 0.000187695}
# {'id': 6, 'article_id': 21482091, 'title': '이런사람들 많나?', 'text': '신입생 새터때 번호교환하고 학교서 인사만좀 하는사이였다가 연락 한 번도 안하고 군대가고 카톡친추는 되어있어서 누군지는 알고 복학하고 오니 서로 얼굴은아는데 인사하기도 민망하고 껄끄러운사이 너무 불편하다 엮일일 없으면 상관없는데 자꾸 마주치면 괜히 불편함', 'category_id': None, 'is_verified': None, 'possible_category_id': 13, 'probs_category_0': 0.00106383, 'probs_category_1': 0.000254189, 'probs_category_2': 4.55929e-05, 'probs_category_3': 0.00116429, 'probs_category_4': 0.00076769, 'probs_category_5': 0.000350276, 'probs_category_6': 0.000236745, 'probs_category_7': 0.00241341, 'probs_category_8': 0.00690792, 'probs_category_9': 0.0101154, 'probs_category_10': 0.00138642, 'probs_category_11': 0.00577934, 'probs_category_12': 0.0151763, 'probs_category_13': 0.954339}
# {'id': 7, 'article_id': 21482097, 'title': '해상도!', 'text': 'UHD 즉 4K면 코딩할때 글자 잘 안보이겠죠?\n그냥 FHD면 충분?', 'category_id': None, 'is_verified': None, 'possible_category_id': 9, 'probs_category_0': 0.000441088, 'probs_category_1': 0.000231478, 'probs_category_2': 0.000123641, 'probs_category_3': 5.43198e-05, 'probs_category_4': 4.93065e-05, 'probs_category_5': 1.54308e-05, 'probs_category_6': 4.28544e-05, 'probs_category_7': 0.0003505, 'probs_category_8': 0.000151603, 'probs_category_9': 0.997291, 'probs_category_10': 0.000285288, 'probs_category_11': 0.000461144, 'probs_category_12': 0.000247539, 'probs_category_13': 0.000255028}
# {'id': 8, 'article_id': 21482121, 'title': '문화유목시대 교재뭔가요', 'text': '정정기간때 신청해서 잘 모르겠어요. ㅠㅠ 계획서보니까 고른다고하는데 뭐에요?', 'category_id': 6, 'is_verified': None, 'possible_category_id': 6, 'probs_category_0': 0.0006123, 'probs_category_1': 0.000707496, 'probs_category_2': 0.00107049, 'probs_category_3': 0.0010099, 'probs_category_4': 0.00373442, 'probs_category_5': 0.00224211, 'probs_category_6': 0.987481, 'probs_category_7': 0.00147074, 'probs_category_8': 0.000533319, 'probs_category_9': 0.000276676, 'probs_category_10': 0.000201142, 'probs_category_11': 0.000278068, 'probs_category_12': 0.000314018, 'probs_category_13': 6.85784e-05}
# {'id': 9, 'article_id': 21482730, 'title': '난', 'text': '멋있어 멋있어', 'category_id': None, 'is_verified': None, 'possible_category_id': 0, 'probs_category_0': 0.922669, 'probs_category_1': 0.000792089, 'probs_category_2': 0.000176011, 'probs_category_3': 0.00142286, 'probs_category_4': 0.00102777, 'probs_category_5': 0.000322282, 'probs_category_6': 0.00165082, 'probs_category_7': 0.000132172, 'probs_category_8': 0.00061508, 'probs_category_9': 0.00245768, 'probs_category_10': 0.000989623, 'probs_category_11': 0.0365588, 'probs_category_12': 0.0301597, 'probs_category_13': 0.00102649}
# {'id': 10, 'article_id': 21483558, 'title': '내일 공강이다', 'text': '불기둥 같은 월화수를 마치고 목금이 오긴 왔네...', 'category_id': None, 'is_verified': None, 'possible_category_id': 3, 'probs_category_0': 0.00393197, 'probs_category_1': 0.000206814, 'probs_category_2': 0.000153013, 'probs_category_3': 0.982244, 'probs_category_4': 0.00382502, 'probs_category_5': 0.000987013, 'probs_category_6': 0.00196211, 'probs_category_7': 0.000504937, 'probs_category_8': 0.00128418, 'probs_category_9': 0.000238033, 'probs_category_10': 0.000174356, 'probs_category_11': 0.00366927, 'probs_category_12': 0.00067672, 'probs_category_13': 0.000142483}
# {'id': 11, 'article_id': 21483780, 'title': '힙동 들어가고싶긴한데', 'text': '커버밖에 못하고\n리얼 힙찔이라 엄두가안난다', 'category_id': None, 'is_verified': None, 'possible_category_id': 11, 'probs_category_0': 0.000616361, 'probs_category_1': 0.000124236, 'probs_category_2': 1.52722e-05, 'probs_category_3': 0.00069582, 'probs_category_4': 9.93055e-05, 'probs_category_5': 0.000146605, 'probs_category_6': 0.000174808, 'probs_category_7': 0.000108595, 'probs_category_8': 0.000445032, 'probs_category_9': 0.000814834, 'probs_category_10': 0.000300445, 'probs_category_11': 0.994003, 'probs_category_12': 0.00215346, 'probs_category_13': 0.0003019}
# {'id': 12, 'article_id': 21483803, 'title': '바람지원했는데요', 'text': '아직 연락이 안왔는데 다들 안온건가요!?', 'category_id': None, 'is_verified': None, 'possible_category_id': 9, 'probs_category_0': 0.0124681, 'probs_category_1': 0.00294971, 'probs_category_2': 0.00348209, 'probs_category_3': 0.0101879, 'probs_category_4': 0.00104862, 'probs_category_5': 0.00114143, 'probs_category_6': 0.0101756, 'probs_category_7': 0.00737637, 'probs_category_8': 0.00235591, 'probs_category_9': 0.853191, 'probs_category_10': 0.00147175, 'probs_category_11': 0.0892864, 'probs_category_12': 0.00419491, 'probs_category_13': 0.00066978}
# {'id': 13, 'article_id': 21483822, 'title': '전자회로실험 파형이 물결처럼 나와야하는데 왜 난 일자로 나오지???;;', 'text': '이번에 복학해서 실험들으려는데 그냥 예비는 똑같이 따라하면 되는거 아닌가?\n왜 일자로만 나와....', 'category_id': 5, 'is_verified': None, 'possible_category_id': 5, 'probs_category_0': 2.75072e-05, 'probs_category_1': 0.000171767, 'probs_category_2': 4.69823e-05, 'probs_category_3': 0.000199981, 'probs_category_4': 0.000331646, 'probs_category_5': 0.997612, 'probs_category_6': 0.000522449, 'probs_category_7': 0.000499409, 'probs_category_8': 0.000146703, 'probs_category_9': 7.12972e-05, 'probs_category_10': 8.93865e-05, 'probs_category_11': 0.000133971, 'probs_category_12': 8.16387e-05, 'probs_category_13': 6.56052e-05}
# {'id': 14, 'article_id': 21484291, 'title': '전자회로실험 파형이 물결처럼 나와야하는데 왜 난 일자로 나오지???;;', 'text': '이번에 복학해서 실험들으려는데 그냥 예비는 똑같이 따라하면 되는거 아닌가?\n왜 일자로만 나와....\n이건 회로인데 뭐가 잘못된거지요????;;', 'category_id': 5, 'is_verified': None, 'possible_category_id': 5, 'probs_category_0': 2.86691e-05, 'probs_category_1': 0.00016577, 'probs_category_2': 4.78963e-05, 'probs_category_3': 0.000194483, 'probs_category_4': 0.000364588, 'probs_category_5': 0.997575, 'probs_category_6': 0.000523782, 'probs_category_7': 0.000495055, 'probs_category_8': 0.000151881, 'probs_category_9': 7.44932e-05, 'probs_category_10': 9.28505e-05, 'probs_category_11': 0.000132923, 'probs_category_12': 8.35122e-05, 'probs_category_13': 6.87802e-05}
# {'id': 15, 'article_id': 21484434, 'title': '이쯤에서 질문', 'text': '전공서적 (2 3 4학년 상관없음)\n1. 새책산다\n2. 중고로 산다\n3. 제본뜬다\n4. 물려받는다\n새책사거나 중고사신분 또 질문\na. 중고로 판다\nb. 그냥 가지고 있는다\nc. 물려준다', 'category_id': None, 'is_verified': None, 'possible_category_id': 4, 'probs_category_0': 0.00670893, 'probs_category_1': 0.0196694, 'probs_category_2': 0.000747558, 'probs_category_3': 0.000733695, 'probs_category_4': 0.947741, 'probs_category_5': 0.00192431, 'probs_category_6': 0.00149116, 'probs_category_7': 0.000527661, 'probs_category_8': 0.0105521, 'probs_category_9': 0.00471319, 'probs_category_10': 0.000551857, 'probs_category_11': 0.000607992, 'probs_category_12': 0.00283592, 'probs_category_13': 0.0011952}
# {'id': 16, 'article_id': 21484856, 'title': '화공과 유기화학1수업 책 : 스미스 유기화학', 'text': '번역판 샀는데 원서없으면 시험보기힘든가요?', 'category_id': None, 'is_verified': None, 'possible_category_id': 5, 'probs_category_0': 2.98099e-05, 'probs_category_1': 0.000164535, 'probs_category_2': 5.06424e-05, 'probs_category_3': 0.000173189, 'probs_category_4': 0.000278484, 'probs_category_5': 0.997677, 'probs_category_6': 0.000606741, 'probs_category_7': 0.000431608, 'probs_category_8': 0.000155807, 'probs_category_9': 6.84042e-05, 'probs_category_10': 8.85745e-05, 'probs_category_11': 0.000125047, 'probs_category_12': 8.22602e-05, 'probs_category_13': 6.82669e-05}
# {'id': 17, 'article_id': 21485394, 'title': '컴퓨터구조 책삽니다', 'text': '표지에 컴퓨터구조 및 설계 써있고 5판 한글판 중고 2만원에삽니다\nPatterson , Hennessy 저자 입니다', 'category_id': 5, 'is_verified': None, 'possible_category_id': 5, 'probs_category_0': 2.91944e-05, 'probs_category_1': 0.000153113, 'probs_category_2': 5.33481e-05, 'probs_category_3': 0.000241867, 'probs_category_4': 0.000324665, 'probs_category_5': 0.997395, 'probs_category_6': 0.000499224, 'probs_category_7': 0.000648634, 'probs_category_8': 0.000162896, 'probs_category_9': 7.78508e-05, 'probs_category_10': 0.000110496, 'probs_category_11': 0.000140872, 'probs_category_12': 8.61497e-05, 'probs_category_13': 7.70214e-05}
# {'id': 18, 'article_id': 21485924, 'title': '오늘 영화의 이해 수업', 'text': '영화의 이해 유양근 교수님 수업을 못가서 그런데 혹시 교재같은거나 해오라고 하신거 있나요?! ㅜㅜ', 'category_id': 6, 'is_verified': None, 'possible_category_id': 6, 'probs_category_0': 0.000361894, 'probs_category_1': 0.000177211, 'probs_category_2': 0.000206004, 'probs_category_3': 0.000323441, 'probs_category_4': 0.000242342, 'probs_category_5': 0.00115263, 'probs_category_6': 0.994885, 'probs_category_7': 0.00109224, 'probs_category_8': 0.000310436, 'probs_category_9': 0.000262725, 'probs_category_10': 0.00018628, 'probs_category_11': 0.000349406, 'probs_category_12': 0.000366237, 'probs_category_13': 8.44446e-05}
# {'id': 19, 'article_id': 21485950, 'title': '초급일본어', 'text': '전유나 초급일본어 책필요한가요?', 'category_id': 6, 'is_verified': None, 'possible_category_id': 6, 'probs_category_0': 0.000313874, 'probs_category_1': 0.000175725, 'probs_category_2': 0.000194509, 'probs_category_3': 0.000222672, 'probs_category_4': 0.000206602, 'probs_category_5': 0.00130886, 'probs_category_6': 0.995402, 'probs_category_7': 0.00072606, 'probs_category_8': 0.000264452, 'probs_category_9': 0.000258286, 'probs_category_10': 0.000151165, 'probs_category_11': 0.000367995, 'probs_category_12': 0.000345979, 'probs_category_13': 6.20374e-05}
# {'id': 20, 'article_id': 21487104, 'title': '나 진짜 어릴 때부터 궁금하던 건데 알려줄 사람', 'text': '버스 안에서 제자리 비행하고 있는 파리는\n버스가 앞으로 움직이면 버스 뒷자석에 부딪혀야 하자나...\n근데 왜 안 부딪혀', 'category_id': None, 'is_verified': None, 'possible_category_id': 9, 'probs_category_0': 0.0145501, 'probs_category_1': 0.000704905, 'probs_category_2': 0.000323076, 'probs_category_3': 0.000785943, 'probs_category_4': 0.000376014, 'probs_category_5': 8.05045e-05, 'probs_category_6': 0.000196909, 'probs_category_7': 0.00282267, 'probs_category_8': 0.000247369, 'probs_category_9': 0.97445, 'probs_category_10': 0.000870283, 'probs_category_11': 0.0026952, 'probs_category_12': 0.00120083, 'probs_category_13': 0.000695873}

# %%
# 데이터 전처리 함수 정의

normal_pattern = re.compile(r'[^ .,?!/@$%~％·∼()\x00-\x7Fㄱ-ㅣ가-힣]+')
url_pattern = re.compile(r'https?:\/\/(www\.)?[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)')

def preprocess(value):
    value = normal_pattern.sub(' ', value)
    value = emoji.replace_emoji(value, replace='')
    value = url_pattern.sub('', value)
    value = repeat_normalize(value, num_repeats=2)
    value = value.strip()
    return value

# %%
# 데이터 전처리

contents = [preprocess(article['title'] + ' ' + article['text']) for article in tqdm(original_articles)]
# Out:
# 100%|██████████| 299314/299314 [00:10<00:00, 29055.95it/s]

# %%
# 전처리된 데이터의 일부를 출력

for content in contents[:20]:
    print(content)
# Out:
# 어제 비마관 화장실에서 핸드폰 찾아주신분! 제가 경황이 없어서 감사하다고도 못 했네요. 정말 감사합니다!!!
# 클럽좋아하시는분 계세요~? 남자 신입생인데 주말에갈려하는데 같이가실분 괌
# 조은문화사 몇시에 보통 열리나요?? 1교시 수업 책 찾아야되서
# 전공수업듣는데 복학한거처럼 보이는 형이 열심히는 하시던데 뭔가 군대갔다고오고 모든걸 까먹은 자기를 자책하듯이 수업듣는걸 보고 나도 3년후에 저러겠구나 싶더라... ㅠㅠ
# 정문에 있는 인쇄집들 몇시까지 하는지 아시나요? 9시 넘어야 갈수있을거 같은데 열어 있을지..
# 이런사람들 많나? 신입생 새터때 번호교환하고 학교서 인사만좀 하는사이였다가 연락 한 번도 안하고 군대가고 카톡친추는 되어있어서 누군지는 알고 복학하고 오니 서로 얼굴은아는데 인사하기도 민망하고 껄끄러운사이 너무 불편하다 엮일일 없으면 상관없는데 자꾸 마주치면 괜히 불편함
# 해상도! UHD 즉 4K면 코딩할때 글자 잘 안보이겠죠? 그냥 FHD면 충분?
# 문화유목시대 교재뭔가요 정정기간때 신청해서 잘 모르겠어요. ㅠㅠ 계획서보니까 고른다고하는데 뭐에요?
# 난 멋있어 멋있어
# 내일 공강이다 불기둥 같은 월화수를 마치고 목금이 오긴 왔네...
# 힙동 들어가고싶긴한데 커버밖에 못하고 리얼 힙찔이라 엄두가안난다
# 바람지원했는데요 아직 연락이 안왔는데 다들 안온건가요!?
# 전자회로실험 파형이 물결처럼 나와야하는데 왜 난 일자로 나오지???;; 이번에 복학해서 실험들으려는데 그냥 예비는 똑같이 따라하면 되는거 아닌가? 왜 일자로만 나와....
# 전자회로실험 파형이 물결처럼 나와야하는데 왜 난 일자로 나오지???;; 이번에 복학해서 실험들으려는데 그냥 예비는 똑같이 따라하면 되는거 아닌가? 왜 일자로만 나와.... 이건 회로인데 뭐가 잘못된거지요????;;
# 이쯤에서 질문 전공서적 (2 3 4학년 상관없음) 1. 새책산다 2. 중고로 산다 3. 제본뜬다 4. 물려받는다 새책사거나 중고사신분 또 질문 a. 중고로 판다 b. 그냥 가지고 있는다 c. 물려준다
# 화공과 유기화학1수업 책 : 스미스 유기화학 번역판 샀는데 원서없으면 시험보기힘든가요?
# 컴퓨터구조 책삽니다 표지에 컴퓨터구조 및 설계 써있고 5판 한글판 중고 2만원에삽니다 Patterson , Hennessy 저자 입니다
# 오늘 영화의 이해 수업 영화의 이해 유양근 교수님 수업을 못가서 그런데 혹시 교재같은거나 해오라고 하신거 있나요?! ㅜㅜ
# 초급일본어 전유나 초급일본어 책필요한가요?
# 나 진짜 어릴 때부터 궁금하던 건데 알려줄 사람 버스 안에서 제자리 비행하고 있는 파리는 버스가 앞으로 움직이면 버스 뒷자석에 부딪혀야 하자나... 근데 왜 안 부딪혀

# %%
# 토크나이저 로드

tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_ID)

print('Original:', contents[0])
print('Tokenized:', tokenizer.tokenize(contents[0]))
# Out:
# Original: 어제 비마관 화장실에서 핸드폰 찾아주신분! 제가 경황이 없어서 감사하다고도 못 했네요. 정말 감사합니다!!!
# Tokenized: ['어제', '비', '##마', '##관', '화장실', '##에서', '핸드폰', '찾아', '##주신', '##분', '!', '제가', '경', '##황', '##이', '없어서', '감사', '##하다고', '##도', '못', '했네요', '.', '정말', '감사합니다', '!', '!', '!']

# %%
# 모델 로드

model = AutoModelForSequenceClassification.from_pretrained(MODEL_ID, num_labels=NUM_LABELS)
model.to(device)
# Out:
# ElectraForSequenceClassification(
#   (electra): ElectraModel(
#     (embeddings): ElectraEmbeddings(
#       (word_embeddings): Embedding(54343, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): ElectraEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): ElectraClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): GELUActivation()
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=14, bias=True)
#   )
# )

# %%
# 모델 세부 정보 수정

model.resize_token_embeddings(len(tokenizer))
# Out:
# Embedding(54343, 768, padding_idx=0)

# %%
# 텍스트 인코딩 및 데이터셋 생성

encodings = tokenizer(
    contents,
    padding=True,
    truncation=True,
    return_tensors='pt',
    max_length=MAX_LENGTH
)
dataset = torch.utils.data.TensorDataset(
    torch.tensor(encodings['input_ids']),
    torch.tensor(encodings['attention_mask'])
)
dataloader = torch.utils.data.DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# /tmp/ipykernel_137163/3188963195.py:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(encodings['input_ids']),
# /tmp/ipykernel_137163/3188963195.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(encodings['attention_mask'])

# %%
# 예측 수행

columns = [
    'id',
    'title',
    'text',
    'category_id',
    'possible_category_id',
    'predicted_category_id',
    *[f'probs_category_{i}' for i in range(NUM_LABELS)]
]
df_results = pd.DataFrame(original_articles, columns=columns)
df_results['category_id'] = df_results['category_id'].fillna(-1).astype(int)

for i, batch in enumerate(tqdm(dataloader, desc='Predicting')):
    input_ids = batch[0].to(device)
    attention_mask = batch[1].to(device)

    with torch.no_grad():
        outputs = model(input_ids, attention_mask=attention_mask)
        logits = outputs.logits
        predictions = torch.argmax(logits, dim=1)
        probabilities = torch.softmax(logits, dim=1)

    start_index = i * BATCH_SIZE
    end_index = start_index + BATCH_SIZE

    df_results.loc[start_index:end_index - 1, 'predicted_category_id'] = predictions.tolist()
    for j in range(NUM_LABELS):
        df_results.loc[start_index:end_index - 1, f'probs_category_{j}'] = probabilities[:, j].tolist()

df_results['predicted_category_id'] = df_results['predicted_category_id'].astype(int)

print('Prediction completed.')
# Out:
# Predicting: 100%|██████████| 9354/9354 [18:29<00:00,  8.43it/s]
# Prediction completed.

# %%
# 예측 결과의 일부를 출력

df_results.head(20)
# Out:
#     id                                    title  \
# 0    1                  어제 비마관 화장실에서 핸드폰 찾아주신분!
# 1    2                           클럽좋아하시는분 계세요~?
# 2    3                      조은문화사 몇시에 보통 열리나요??
# 3    4                                  전공수업듣는데
# 4    5               정문에 있는 인쇄집들 몇시까지 하는지 아시나요?
# 5    6                                이런사람들 많나?
# 6    7                                     해상도!
# 7    8                             문화유목시대 교재뭔가요
# 8    9                                        난
# 9   10                                  내일 공강이다
# 10  11                              힙동 들어가고싶긴한데
# 11  12                                 바람지원했는데요
# 12  13  전자회로실험 파형이 물결처럼 나와야하는데 왜 난 일자로 나오지???;;
# 13  14  전자회로실험 파형이 물결처럼 나와야하는데 왜 난 일자로 나오지???;;
# 14  15                                  이쯤에서 질문
# 15  16                 화공과 유기화학1수업 책 : 스미스 유기화학
# 16  17                               컴퓨터구조 책삽니다
# 17  18                             오늘 영화의 이해 수업
# 18  19                                    초급일본어
# 19  20               나 진짜 어릴 때부터 궁금하던 건데 알려줄 사람
#
#                                                  text  category_id  \
# 0               제가 경황이 없어서 감사하다고도 못 했네요.\n정말 감사합니다!!!            9
# 1                           남자 신입생인데 주말에갈려하는데 같이가실분 괌           -1
# 2                                      1교시 수업 책 찾아야되서            7
# 3   복학한거처럼 보이는 형이 열심히는 하시던데 뭔가 군대갔다고오고 모든걸 까먹은 자기를...            4
# 4                          9시 넘어야 갈수있을거 같은데\n열어 있을지..            7
# 5   신입생 새터때 번호교환하고 학교서 인사만좀 하는사이였다가 연락 한 번도 안하고 군대...           -1
# 6             UHD 즉 4K면 코딩할때 글자 잘 안보이겠죠?\n그냥 FHD면 충분?           -1
# 7          정정기간때 신청해서 잘 모르겠어요. ㅠㅠ 계획서보니까 고른다고하는데 뭐에요?            6
# 8                                             멋있어 멋있어           -1
# 9                        불기둥 같은 월화수를 마치고 목금이 오긴 왔네...           -1
# 10                           커버밖에 못하고\n리얼 힙찔이라 엄두가안난다           -1
# 11                             아직 연락이 안왔는데 다들 안온건가요!?           -1
# 12  이번에 복학해서 실험들으려는데 그냥 예비는 똑같이 따라하면 되는거 아닌가?\n왜 일...            5
# 13  이번에 복학해서 실험들으려는데 그냥 예비는 똑같이 따라하면 되는거 아닌가?\n왜 일...            5
# 14  전공서적 (2 3 4학년 상관없음)\n1. 새책산다\n2. 중고로 산다\n3. 제본...           -1
# 15                            번역판 샀는데 원서없으면 시험보기힘든가요?           -1
# 16  표지에 컴퓨터구조 및 설계 써있고 5판 한글판 중고 2만원에삽니다\nPatterso...            5
# 17  영화의 이해 유양근 교수님 수업을 못가서 그런데 혹시 교재같은거나 해오라고 하신거 ...            6
# 18                                  전유나 초급일본어 책필요한가요?            6
# 19  버스 안에서 제자리 비행하고 있는 파리는\n버스가 앞으로 움직이면 버스 뒷자석에 부...           -1
#
#     possible_category_id  predicted_category_id  probs_category_0  \
# 0                      9                      9          0.000402
# 1                     11                     11          0.001315
# 2                      7                      7          0.000058
# 3                      4                      4          0.000145
# 4                      7                      7          0.000058
# 5                     13                      3          0.000262
# 6                      9                      9          0.003065
# 7                      6                      6          0.000327
# 8                      0                     11          0.139631
# 9                      3                      3          0.000615
# 10                    11                      3          0.001014
# 11                     9                     11          0.001460
# 12                     5                      5          0.000071
# 13                     5                      5          0.000066
# 14                     4                      4          0.002446
# 15                     5                      5          0.000063
# 16                     5                      5          0.000071
# 17                     6                      6          0.000270
# 18                     6                      6          0.000482
# 19                     9                      3          0.015825
#
#     probs_category_1  probs_category_2  probs_category_3  probs_category_4  \
# 0           0.000042          0.000172          0.000935          0.000105
# 1           0.000199          0.000411          0.020121          0.000892
# 2           0.000073          0.000217          0.000512          0.000049
# 3           0.001008          0.000088          0.001051          0.994564
# 4           0.000065          0.000179          0.000372          0.000043
# 5           0.000028          0.000298          0.992901          0.000673
# 6           0.001443          0.000989          0.001187          0.002339
# 7           0.000101          0.000119          0.000305          0.000189
# 8           0.000329          0.000337          0.017059          0.001653
# 9           0.000207          0.000422          0.901717          0.078381
# 10          0.000140          0.000324          0.539318          0.001277
# 11          0.000038          0.000057          0.023806          0.000429
# 12          0.000151          0.000120          0.000042          0.000427
# 13          0.000142          0.000115          0.000042          0.000450
# 14          0.001172          0.000372          0.005352          0.968152
# 15          0.000117          0.000099          0.000038          0.000406
# 16          0.000150          0.000115          0.000045          0.000400
# 17          0.000116          0.000135          0.000211          0.000175
# 18          0.000103          0.000134          0.000268          0.000157
# 19          0.000818          0.000777          0.540253          0.196866
#
#     probs_category_5  probs_category_6  probs_category_7  probs_category_8  \
# 0           0.000064          0.000027          0.002770          0.000422
# 1           0.000532          0.000607          0.000539          0.001535
# 2           0.000188          0.000114          0.997310          0.000058
# 3           0.001193          0.000408          0.000070          0.000892
# 4           0.000166          0.000088          0.997247          0.000062
# 5           0.000036          0.000106          0.000487          0.000206
# 6           0.000502          0.000106          0.001436          0.003643
# 7           0.000508          0.997328          0.000436          0.000127
# 8           0.001403          0.006289          0.000544          0.001067
# 9           0.000840          0.007140          0.000735          0.001298
# 10          0.000348          0.000886          0.000370          0.000773
# 11          0.000468          0.004585          0.000308          0.000332
# 12          0.997688          0.000621          0.000236          0.000217
# 13          0.997716          0.000601          0.000236          0.000219
# 14          0.004685          0.000744          0.000195          0.009159
# 15          0.997686          0.000817          0.000190          0.000222
# 16          0.997693          0.000559          0.000303          0.000227
# 17          0.000743          0.997049          0.000616          0.000132
# 18          0.000528          0.996866          0.000590          0.000151
# 19          0.003755          0.002520          0.005206          0.014202
#
#     probs_category_9  probs_category_10  probs_category_11  probs_category_12  \
# 0           0.993802           0.000713           0.000102           0.000426
# 1           0.089414           0.004382           0.665849           0.213209
# 2           0.000183           0.001095           0.000056           0.000024
# 3           0.000094           0.000035           0.000176           0.000218
# 4           0.000265           0.001332           0.000047           0.000022
# 5           0.002548           0.000098           0.001621           0.000703
# 6           0.982826           0.000975           0.000162           0.001243
# 7           0.000024           0.000147           0.000318           0.000023
# 8           0.001770           0.001943           0.806714           0.019629
# 9           0.000752           0.000150           0.006961           0.000679
# 10          0.001800           0.000803           0.448520           0.003820
# 11          0.002095           0.000844           0.963703           0.001739
# 12          0.000047           0.000095           0.000178           0.000036
# 13          0.000045           0.000091           0.000170           0.000035
# 14          0.003718           0.000113           0.000855           0.002932
# 15          0.000043           0.000076           0.000154           0.000031
# 16          0.000053           0.000101           0.000175           0.000038
# 17          0.000026           0.000186           0.000265           0.000023
# 18          0.000035           0.000231           0.000375           0.000023
# 19          0.073416           0.001931           0.097437           0.046224
#
#     probs_category_13
# 0            0.000018
# 1            0.000994
# 2            0.000061
# 3            0.000058
# 4            0.000054
# 5            0.000032
# 6            0.000082
# 7            0.000049
# 8            0.001632
# 9            0.000102
# 10           0.000606
# 11           0.000136
# 12           0.000073
# 13           0.000072
# 14           0.000105
# 15           0.000058
# 16           0.000071
# 17           0.000054
# 18           0.000058
# 19           0.000770

# %%
# 평가 지표 계산 함수 정의

def calculate_metrics(true_labels, predicted_labels):
    acc = accuracy_score(true_labels, predicted_labels)
    prec = precision_score(true_labels, predicted_labels, average=METRIC_AVERAGE, zero_division=METRIC_ZERO_DIVISION)
    rec = recall_score(true_labels, predicted_labels, average=METRIC_AVERAGE, zero_division=METRIC_ZERO_DIVISION)
    f1 = f1_score(true_labels, predicted_labels, average=METRIC_AVERAGE, zero_division=METRIC_ZERO_DIVISION)

    return acc, prec, rec, f1

# %%
# 평가 지표 출력

labels = []
predictions = []

for i in range(len(df_results)):
    if df_results.loc[i, 'category_id'] != -1:
        labels.append(df_results.loc[i, 'category_id'])
        predictions.append(df_results.loc[i, 'predicted_category_id'])

acc, prec, rec, f1 = calculate_metrics(labels, predictions)

print(f'Accuracy: {acc:.4f}')
print(f'Precision: {prec:.4f}')
print(f'Recall: {rec:.4f}')
print(f'F1 Score: {f1:.4f}')
# Out:
# Accuracy: 0.9915
# Precision: 0.9915
# Recall: 0.9915
# F1 Score: 0.9914

# %%
# 예측 결과의 비율을 출력

threshold_counts = [0] * NUM_LABELS
total_count = len(df_results)

for i in range(NUM_LABELS):
    column_name = f'probs_category_{i}'
    threshold_counts[i] = (df_results[column_name] > THRESHOLD).sum()

threshold_percentages = [(count / total_count * 100) for count in threshold_counts]

for i in range(NUM_LABELS):
    print(f'{CATEGORIES[i]} ({i}): {threshold_counts[i]} ({threshold_percentages[i]:.2f}%)')

plt.figure(figsize=(12, 8))
plt.bar(range(NUM_LABELS), threshold_counts)
for i, count in enumerate(threshold_counts):
    plt.text(i, count + 0.1, f'{count} ({threshold_percentages[i]:.2f}%)', ha='center')
plt.xlabel(f'Threshold ({THRESHOLD})')
plt.ylabel('Count')
plt.xticks(range(NUM_LABELS))
plt.title('Distribution of Predictions Above Threshold by Category')
plt.show()
# Out:
# 자유 (0): 37886 (12.66%)
# 학사 (1): 15188 (5.07%)
# 장학 · 행정 (2): 11084 (3.70%)
# 학교생활 (3): 18009 (6.02%)
# 수업 (4): 31005 (10.36%)
# 수업/이과 (5): 34418 (11.50%)
# 수업/문과 (6): 32802 (10.96%)
# 캠퍼스 (7): 25827 (8.63%)
# 취업 · 진로 (8): 13981 (4.67%)
# 일상생활 (9): 27506 (9.19%)
# 음식점 · 카페 (10): 6725 (2.25%)
# 취미 · 여가 (11): 20075 (6.71%)
# 인간관계 (12): 9805 (3.28%)
# 병역 (13): 5657 (1.89%)

# %%
# 기존 카테고리와 예측 카테고리가 다른 경우의 비율을 출력

changed_counts = [0] * NUM_LABELS
total_count = len(df_results)

for i in range(total_count):
    possible_category_id = df_results.loc[i, 'possible_category_id']
    predicted_category_id = df_results.loc[i, 'predicted_category_id']
    if possible_category_id != predicted_category_id:
        changed_counts[possible_category_id] += 1

changed_percentages = [(count / total_count * 100) for count in changed_counts]
total_changed_count = sum(changed_counts)
total_changed_percentage = total_changed_count / total_count * 100

print(f'Total changed count: {total_changed_count} ({total_changed_percentage:.2f}%)')
for i in range(NUM_LABELS):
    print(f'{CATEGORIES[i]} [{i}]: {changed_counts[i]} ({changed_percentages[i]:.2f}%)')

plt.figure(figsize=(12, 8))
plt.bar(range(NUM_LABELS), changed_counts)
for i, count in enumerate(changed_counts):
    plt.text(i, count + 0.1, f'{count} ({changed_percentages[i]:.2f}%)', ha='center')
plt.xlabel('Category')
plt.ylabel('Changed Count')
plt.xticks(range(NUM_LABELS))
plt.title('Distribution of Changed Predictions by Category')
plt.tight_layout()
plt.show()
# Out:
# Total changed count: 83554 (27.92%)
# 자유 [0]: 12025 (4.02%)
# 학사 [1]: 10314 (3.45%)
# 장학 · 행정 [2]: 3344 (1.12%)
# 학교생활 [3]: 4679 (1.56%)
# 수업 [4]: 10746 (3.59%)
# 수업/이과 [5]: 12469 (4.17%)
# 수업/문과 [6]: 2395 (0.80%)
# 캠퍼스 [7]: 3383 (1.13%)
# 취업 · 진로 [8]: 4884 (1.63%)
# 일상생활 [9]: 10241 (3.42%)
# 음식점 · 카페 [10]: 444 (0.15%)
# 취미 · 여가 [11]: 5598 (1.87%)
# 인간관계 [12]: 1918 (0.64%)
# 병역 [13]: 1114 (0.37%)

# %%
# 예측 결과를 DB에 저장

connection = db.get_connection()
cursor = connection.cursor()

sql_template = f'''
    INSERT INTO {TABLE_NAME} (id, possible_category_id, {{columns}})
    VALUES (%s, %s, {{placeholders}})
    ON DUPLICATE KEY UPDATE
        possible_category_id = VALUES(possible_category_id),
        {{updates}}
'''

columns = ', '.join([f'probs_category_{i}' for i in range(NUM_LABELS)])
placeholders = ', '.join(['%s' for _ in range(NUM_LABELS)])
updates = ', '.join([f'probs_category_{i} = VALUES(probs_category_{i})' for i in range(NUM_LABELS)])

sql = sql_template.format(columns=columns, placeholders=placeholders, updates=updates)
values = [(row['id'], row['predicted_category_id'],) + tuple(row[f'probs_category_{i}'] for i in range(NUM_LABELS)) for _, row in df_results.iterrows()]

cursor.executemany(sql, values)
connection.commit()

cursor.close()
db.close_connection()
# Out:
# Connected to DB successfully.
